# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker
from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#Convert 'WeekID' to DateTime Object & Check First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                         url     WeekID  \
# 18553    http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 103337   http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 300806  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
# 152154  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
#
#         Week Position                      Song  \
# 18553              63  High School Confidential
# 103337             98           Little Serenade
# 300806             61             Almost Maybes
# 152154             78               White Teeth
#
#                                     Performer  \
# 18553   Jerry Lee Lewis And His Pumping Piano
# 103337                      The Ames Brothers
# 300806                           Jordan Davis
# 152154             YoungBoy Never Broke Again
#
#                                                                SongID  \
# ...

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#Merge BB with Features
bb100_f = pd.merge(bb100, features, on='SongID', how='left')

# %%
#Sort merged dataframe by 'Valence' (removing 'NaNs' and '0' values) from Happy to Sad.  
bb100_f.dropna(subset=['valence'], inplace=True)
bb100_f = bb100_f[bb100_f['valence'] !=0 ]
bb100_f.sort_values(by='valence', ascending=False, inplace=True)
bb100_Happiest = bb100_f.iloc[np.r_[0:1, -1:0]]
bb100_Happiest
# Out:
#                                                        url     WeekID  \
# 222644  http://www.billboard.com/charts/hot-100/1961-07-29 1961-07-29
# 52110   http://www.billboard.com/charts/hot-100/2014-05-03 2014-05-03
#
#         Week Position                        Song_x   Performer_x  \
# 222644             31  I'm Gonna Knock On Your Door  Eddie Hodges
# 52110              84                      Midnight      Coldplay
#
#                                           SongID  Instance  \
# 222644  I'm Gonna Knock On Your DoorEddie Hodges         1
# 52110                           MidnightColdplay         1
#
#         Previous Week Position  Peak Position  Weeks on Chart   Performer_y  \
# 222644                    38.0             31               7  Eddie Hodges
# 52110                      NaN             84               1      Coldplay
#
#                               Song_y              spotify_genre  \
# 222644  I'm Gonna Knock On Your Door                         []
# ...

# %%
#Play Happiest Song:
import webbrowser
Happiest_URL = bb100_Happiest['spotify_track_preview_url'].iloc[0]
webbrowser.open_new(Happiest_URL)
# Out:
# True

# %%
#Play Saddest Song:
import webbrowser
Saddest_URL = bb100_Happiest['spotify_track_preview_url'].iloc[1]
webbrowser.open_new(Saddest_URL)
# Out:
# True
