# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker
from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                         url     WeekID  \
# 18553    http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 103337   http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 300806  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
# 152154  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
#
#         Week Position                      Song  \
# 18553              63  High School Confidential
# 103337             98           Little Serenade
# 300806             61             Almost Maybes
# 152154             78               White Teeth
#
#                                     Performer  \
# 18553   Jerry Lee Lewis And His Pumping Piano
# 103337                      The Ames Brothers
# 300806                           Jordan Davis
# 152154             YoungBoy Never Broke Again
#
#                                                                SongID  \
# 18553   High School ConfidentialJerry Lee Lewis And His Pumping Piano
# 103337                               Little SerenadeThe Ames Brothers
# 300806                                      Almost MaybesJordan Davis
# 152154                          White TeethYoungBoy Never Broke Again
#
#         Instance  Previous Week Position  Peak Position  Weeks on Chart
# 18553          1                     NaN             63               1
# 103337         1                     NaN             98               1
# 300806         2                    64.0             61              17
# 152154         1                     NaN             78               1

# %%
#Split the Dataframes by Decade from 60s, 70s, 80s, 90s, 2000s, 2010s
bb60s = bb100[(bb100['WeekID'] >= '1960-1-1') & (bb100['WeekID'] < '1970-1-1')]
bb70s = bb100[(bb100['WeekID'] >= '1970-1-1') & (bb100['WeekID'] < '1980-1-1')]
bb80s = bb100[(bb100['WeekID'] >= '1980-1-1') & (bb100['WeekID'] < '1990-1-1')]
bb90s = bb100[(bb100['WeekID'] >= '1990-1-1') & (bb100['WeekID'] < '2000-1-1')]
bb2000s = bb100[(bb100['WeekID'] >= '2000-1-1') & (bb100['WeekID'] < '2010-1-1')]
bb2010s = bb100[(bb100['WeekID'] >= '2010-1-1') & (bb100['WeekID'] < '2020-1-1')]

# %%
#Add Decade Column to Dataframe:
def decade_to_df(df, decade_as_string):
    return df.assign(Decade=decade_as_string)

# %%
#Execute the decade_to_df function on split dataframes:
bb60s = decade_to_df(bb60s, '1960s')
bb70s = decade_to_df(bb70s, '1970s')
bb80s = decade_to_df(bb80s, '1980s')
bb90s = decade_to_df(bb90s, '1990s')
bb2000s = decade_to_df(bb2000s, '2000s')
bb2010s = decade_to_df(bb2010s, '2010s')

# %%
#Check results of function
bb2010s.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                         url     WeekID  \
# 45759    http://www.billboard.com/charts/hot-100/2010-01-02 2010-01-02
# 242592   http://www.billboard.com/charts/hot-100/2010-01-02 2010-01-02
# 169774  https://www.billboard.com/charts/hot-100/2019-12-28 2019-12-28
# 197357  https://www.billboard.com/charts/hot-100/2019-12-28 2019-12-28
#
#         Week Position                 Song  \
# 45759              84              On Fire
# 242592             26        Money To Blow
# 169774             53  Like It's Christmas
# 197357             35                 Woah
#
#                                   Performer  \
# 45759                             Lil Wayne
# 242592  Birdman Featuring Lil Wayne & Drake
# 169774                       Jonas Brothers
# 197357                             Lil Baby
#
#                                                   SongID  Instance  \
# 45759                                   On FireLil Wayne         1
# 242592  Money To BlowBirdman Featuring Lil Wayne & Drake         1
# 169774                 Like It's ChristmasJonas Brothers         1
# 197357                                      WoahLil Baby         1
#
#         Previous Week Position  Peak Position  Weeks on Chart Decade
# 45759                     62.0             62               2  2010s
# 242592                    26.0             26              11  2010s
# 169774                    61.0             53               3  2010s
# 197357                    28.0             16               6  2010s

# %%
#Stack all dataframes on top of each other:
bb_all_decade = pd.concat([bb60s, bb70s, bb80s, bb90s, bb2000s, bb2010s])

# %%
#Extract all weeks with #1 Song
bb1_w_decade = bb_all_decade[bb_all_decade['Week Position']==1].copy()

# %%
#Check the dataframe
bb1_w_decade.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                         url     WeekID  \
# 226796   http://www.billboard.com/charts/hot-100/1960-01-02 1960-01-02
# 232846   http://www.billboard.com/charts/hot-100/1960-01-09 1960-01-09
# 304046  https://www.billboard.com/charts/hot-100/2019-12-21 2019-12-21
# 304047  https://www.billboard.com/charts/hot-100/2019-12-28 2019-12-28
#
#         Week Position                             Song      Performer  \
# 226796              1                          El Paso  Marty Robbins
# 232846              1                          El Paso  Marty Robbins
# 304046              1  All I Want For Christmas Is You   Mariah Carey
# 304047              1  All I Want For Christmas Is You   Mariah Carey
#
#                                              SongID  Instance  \
# 226796                         El PasoMarty Robbins         1
# 232846                         El PasoMarty Robbins         1
# 304046  All I Want For Christmas Is YouMariah Carey         9
# 304047  All I Want For Christmas Is YouMariah Carey         9
#
#         Previous Week Position  Peak Position  Weeks on Chart Decade
# 226796                     2.0              1               9  1960s
# 232846                     1.0              1              10  1960s
# 304046                     3.0              1              34  2010s
# 304047                     1.0              1              35  2010s

# %%
#Check for Null Values By Column: 
bb1_w_decade.isnull().sum()
# Out:
# url                        0
# WeekID                     0
# Week Position              0
# Song                       0
# Performer                  0
# SongID                     0
# Instance                   0
# Previous Week Position    36
# Peak Position              0
# Weeks on Chart             0
# Decade                     0
# dtype: int64

# %%
#Check Dimensions
bb1_w_decade.shape
# Out:
# (3131, 11)

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#Merge bb1_w_decade & features: 
decade_features = pd.merge(bb1_w_decade, features.drop_duplicates(subset=['SongID']), on='SongID', how='left')
decade_features.head(3)
# Out:
#                                                   url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1962-12-22 1962-12-22
# 1  http://www.billboard.com/charts/hot-100/1962-12-29 1962-12-29
# 2  http://www.billboard.com/charts/hot-100/1963-01-05 1963-01-05
#
#    Week Position   Song_x    Performer_x                SongID  Instance  \
# 0              1  Telstar  The Tornadoes  TelstarThe Tornadoes         1
# 1              1  Telstar  The Tornadoes  TelstarThe Tornadoes         1
# 2              1  Telstar  The Tornadoes  TelstarThe Tornadoes         1
#
#    Previous Week Position  Peak Position  Weeks on Chart Decade  \
# 0                     5.0              1               8  1960s
# 1                     1.0              1               9  1960s
# 2                     1.0              1              10  1960s
#
#      Performer_y   Song_y   spotify_genre        spotify_track_id  \
# 0  The Tornadoes  Telstar  ['surf music']  5NIb0uP4CO3ckfyCIjjcFx
# 1  The Tornadoes  Telstar  ['surf music']  5NIb0uP4CO3ckfyCIjjcFx
# 2  The Tornadoes  Telstar  ['surf music']  5NIb0uP4CO3ckfyCIjjcFx
#
#                                                                                      spotify_track_preview_url  \
# 0  https://p.scdn.co/mp3-preview/b699d5122d2a509902ece8b17b5e03ebe9827b71?cid=b8d3901151d34489a160e3cf0ab1fa94
# 1  https://p.scdn.co/mp3-preview/b699d5122d2a509902ece8b17b5e03ebe9827b71?cid=b8d3901151d34489a160e3cf0ab1fa94
# 2  https://p.scdn.co/mp3-preview/b699d5122d2a509902ece8b17b5e03ebe9827b71?cid=b8d3901151d34489a160e3cf0ab1fa94
#
#    spotify_track_duration_ms  spotify_track_explicit  \
# 0                   198960.0                     0.0
# 1                   198960.0                     0.0
# 2                   198960.0                     0.0
#
#                           spotify_track_album  danceability  energy  key  \
# 0  Mad Men (Music from the Original TV Series         0.289   0.728  6.0
# 1  Mad Men (Music from the Original TV Series         0.289   0.728  6.0
# 2  Mad Men (Music from the Original TV Series         0.289   0.728  6.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -6.495   0.0       0.0385      0.000368             0.929     0.381
# 1    -6.495   0.0       0.0385      0.000368             0.929     0.381
# 2    -6.495   0.0       0.0385      0.000368             0.929     0.381
#
#    valence    tempo  time_signature  spotify_track_popularity
# 0    0.539  143.988             4.0                       8.0
# 1    0.539  143.988             4.0                       8.0
# 2    0.539  143.988             4.0                       8.0

# %%
decade_features.shape
# Out:
# (3131, 32)

# %%
decade_features.isnull().sum()
# Out:
# url                             0
# WeekID                          0
# Week Position                   0
# Song_x                          0
# Performer_x                     0
# SongID                          0
# Instance                        0
# Previous Week Position         36
# Peak Position                   0
# Weeks on Chart                  0
# Decade                          0
# Performer_y                     0
# Song_y                          0
# spotify_genre                 160
# spotify_track_id              337
# spotify_track_preview_url    1563
# spotify_track_duration_ms     337
# spotify_track_explicit        337
# spotify_track_album           337
# danceability                  337
# energy                        337
# key                           337
# loudness                      337
# mode                          337
# speechiness                   337
# acousticness                  337
# instrumentalness              337
# liveness                      337
# valence                       337
# tempo                         337
# time_signature                337
# spotify_track_popularity      337
# dtype: int64

# %%
#Drop Null Values as Preprocessing Step
no_null_list = ["energy", "liveness", "tempo", "valence", "loudness", "speechiness", "acousticness", "danceability", "instrumentalness"]
decade_features = decade_features.dropna(subset=no_null_list)
print(len(decade_features))
decade_features.isnull().sum()
# Out:
# 2794
# url                             0
# WeekID                          0
# Week Position                   0
# Song_x                          0
# Performer_x                     0
# SongID                          0
# Instance                        0
# Previous Week Position         33
# Peak Position                   0
# Weeks on Chart                  0
# Decade                          0
# Performer_y                     0
# Song_y                          0
# spotify_genre                  14
# spotify_track_id                0
# spotify_track_preview_url    1226
# spotify_track_duration_ms       0
# spotify_track_explicit          0
# spotify_track_album             0
# danceability                    0
# energy                          0
# key                             0
# loudness                        0
# mode                            0
# speechiness                     0
# acousticness                    0
# instrumentalness                0
# liveness                        0
# valence                         0
# tempo                           0
# time_signature                  0
# spotify_track_popularity        0
# dtype: int64

# %%
keep = ["energy", "liveness", "tempo", "valence", "loudness", 
        "speechiness", "acousticness", "danceability", "instrumentalness"]

X = decade_features[keep].values
decade = decade_features.Decade
preview = decade_features.spotify_track_preview_url
popularity = decade_features.spotify_track_popularity

min_max_scaler = MinMaxScaler()
X = min_max_scaler.fit_transform(X)

pca = PCA(n_components=3)
pca.fit(X)

X = pca.transform(X)

three_D_df = pd.DataFrame({'Decade':decade, 'col_x':X[:,0], 
                           'col_y':X[:,1], 'col_z':X[:,2],
                           'popularity':popularity, 
                           'link':preview})


three_D = px.scatter_3d(three_D_df, x='col_x', y='col_y', z='col_z',
                       color='Decade', size='popularity',
                       template='plotly_dark')

three_D.show()
# Out:
# <div>                            <div id="d9f103d7-3da1-4a62-8ed9-96ddb53fcb69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9f103d7-3da1-4a62-8ed9-96ddb53fcb69")) {                    Plotly.newPlot(                        "d9f103d7-3da1-4a62-8ed9-96ddb53fcb69",                        [{"hovertemplate":"Decade=1960s<br>col_x=%{x}<br>col_y=%{y}<br>col_z=%{z}<br>popularity=%{marker.size}<extra></extra>","legendgroup":"1960s","marker":{"color":"#636efa","size":[8.0,8.0,8.0,29.0,29.0,66.0,49.0,64.0,64.0,64.0,64.0,66.0,66.0,66.0,66.0,59.0,51.0,61.0,61.0,57.0,41.0,52.0,60.0,63.0,73.0,44.0,56.0,42.0,66.0,69.0,70.0,64.0,58.0,58.0,58.0,66.0,69.0,70.0,50.0,68.0,55.0,61.0,62.0,69.0,68.0,54.0,68.0,47.0,39.0,76.0,76.0,56.0,56.0,56.0,56.0,56.0,56.0,56.0,56.0,56.0,49.0,49.0,49.0,49.0,49.0,35.0,35.0,35.0,35.0,68.0,42.0,42.0,59.0,59.0,59.0,59.0,67.0,49.0,49.0,55.0,55.0,67.0,67.0,67.0,51.0,62.0,61.0,57.0,69.0,73.0,42.0,68.0,32.0,45.0,41.0,62.0,32.0,61.0,73.0,68.0,0.0,7.0,61.0,50.0,66.0,55.0,70.0,64.0,60.0,78.0,64.0,69.0,45.0,79.0,64.0,33.0,43.0,44.0,50.0,70.0,51.0,32.0,50.0,32.0,57.0,52.0,43.0,61.0,60.0,52.0,51.0,50.0,55.0,70.0,67.0,78.0,47.0,64.0,43.0,33.0,73.0,55.0,44.0,61.0,59.0,41.0,63.0,60.0,30.0,53.0,51.0,64.0,62.0,41.0,42.0,46.0,46.0,46.0,46.0,46.0,46.0,46.0