# %% [markdown]
# ![title](BB_Spot.png)

# %% [markdown]
# ![image alt ><](BB_Spot.png)

# %% [markdown]
# <div style="text-align: center"><img src="BB_Spot.png" width="1000" /></div>

# %% [markdown]
# <center>
#
# ![image](BB_Spot.png)
# </center>

# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto">

# %%
# %%HTML
#
# <style>
# td {
#   font-size: 10px
# }
# </style>
# Out:
# <style>
# td {
#   font-size: 10px
# }
# </style>

# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto" width="400">
#
#
# | Billboard Data   |   Spotify Data |
# | :- | -: |
# | Weekly Top 100 (1958~2021)   |   Music Genres
# | Song Name   |   Audio Features
# | Performer Name   |   Popularity

# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto" width="600">

# %%
# %%HTML
#
# <style>
# td {
#   font-size: 40px
# }
# </style>
# Out:
# <style>
# td {
#   font-size: 40px
# }
# </style>

# %% [markdown]
# | Billboard Data   |   Spotify Data |
# | :- | -: |
# | Top 100 Songs   |   Audio Features
# | Weekly Ranking   |   Music Genre
# | 1958~2021   |   Popularity

# %% [markdown]
# ## <center> Question: Longest Number 1 Streak On Billboard Hot 100? </center> ##

# %% [markdown]
# | Song   |   Performer |
# | :- | -: |
# | A. Shape Of You   |   Ed Sheeran
# | B. Macarena   |   Los Del Rio
# | C. Old Town Road   |   Lil Nas X (feat. Billy Ray Cyrus)
# | D. Hello   |   Adele

# %% [markdown]
# ## <center> Answer </center> ##

# %%
from IPython.display import Audio
Audio('Old_Town_Road.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="Top1s.png" style="margin:auto">

# %%
from IPython.display import Image
Image(filename='SongsOne.png') 

#<img src="SongsOne.png" style="margin:auto" width=1200>

# %% [markdown]
# # <center> Spotify Genres</center> #

# %%
#from IPython.display import Image
#Image(filename='WC.png', style="margin-left:auto; margin-right:auto")

# %% [markdown]
# <img src="WC.png" style="margin:auto">

# %% [markdown]
# <div align="center"><a href="https://everynoise.com/engenremap.html">Every Noise At Once</a> </div>

# %% [markdown]
# <img src="Spotify_Bubbles.png" style="margin:auto">

# %% [markdown]
# # <center> Spotify Genres: "Don't Burst My Bubble!" </center> #

# %% [markdown]
# <img src="Spotify_Bubbles_Burst.png" style="margin:auto">

# %% [markdown]
# # <center> Cross Analysis: Genre Popularity across Spotify & Billboard </center> #

# %% [markdown]
# <img src="Genre_BB_vs_S.png" style="margin:auto">

# %% [markdown]
# # <center> Introducing Spotify Audio Features </center> #

# %% [markdown]
# # <center> Danceability </center> #

# %% [markdown]
# ## <center> Danceability High</center> ##

# %%
Audio('Dance_Score_0.88.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## <center> Danceability Low</center> ##

# %%
Audio('Dance_Score_0.42.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="DanceTime.png" style="margin:auto">

# %% [markdown]
# <img src="I_vs_S_Era.png" style="margin:auto">

# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto" width="400">
#
#
# | Billboard Data   |   Spotify Data |
# | :- | -: |
# | Weekly Top 100 (1958~2021)     |     Audio Features

# %%
# %%html
# <style>
# table (float:left)
# </style>
# Out:
# <style>
# table (float:left)
# </style>

# %%
from IPython.display import Video

Video("Spotify_Animation.mp4")
# Out:
# <video src="Spotify_Animation.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Audio
Audio('Dance_Score_0.88.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
