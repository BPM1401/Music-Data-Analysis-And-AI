# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto">

# %% [markdown]
# ### <center><i>Listening To Data</i></center> ###

# %% [markdown]
# <img src="BB_Spot.png" style="margin:auto" width="400">
#
#
# | Billboard Data   |   Spotify Data |
# | :- | -: |
# | Weekly Top 100 (1958~2021)     |     Audio Features

# %% [markdown]
# ### <center>Multiple Choice Question:</center> ###
# ### <center>Which song held the Number 1 Spot for most consecutive weeks?</center> ###

# %% [markdown]
# | Song   |   Performer |
# | :- | -: |
# | A. Shape Of You   |   Ed Sheeran
# | B. Macarena   |   Los Del Rio
# | C. Old Town Road   |   Lil Nas X (feat. Billy Ray Cyrus)
# | D. Hello   |   Adele

# %% [markdown]
# ## <center> Answer </center> ##

# %% [markdown]
# <img src="Top1s.png" style="margin:auto" width='650' height='750'>

# %%
from IPython.display import Audio
Audio('Old_Town_Road.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="BB.png" style="margin:auto">

# %% [markdown]
# Billboard Data ~ 1958 to 2021  |
# :- |
# Top 100   |
# Song Name   |
# Performer Name   |

# %%
# %%html
# <style>
# table (float:left)
# </style>
# Out:
# <style>
# table (float:left)
# </style>

# %% [markdown]
# ### <center>What are the audio features of "Old Town Road"?</center> ###

# %% [markdown]
# <img src="Spot.png" style="margin:auto" width='300' height='300'>

# %% [markdown]
# Spotify Data  |
# :- |
# Acoustic Features|
# Music Genres   |
# Popularity   |

# %% [markdown]
# ### <center>How Has Music Changed Over Time?</center> ###

# %% [markdown]
# <img src="SvI.png" style="margin:auto">

# %% [markdown]
# #### <center>Sample Music</center> ####

# %%
from IPython.display import Audio
Audio('Instrumental_Score_0.949.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('Speechy_Score_0.501.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## <center>High Speechiness !</center> ##

# %%
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <img src="InsTime.png" style="margin:auto">

# %% [markdown]
# ### <center>How Has Speechiness Varied Over Time?</center> ###

# %% [markdown]
# <img src="SpeTime.png" style="margin:auto">

# %% [markdown]
# ### <center>Instrumentalness Vs Speechiness</center> ###

# %% [markdown]
# <img src="I_vs_S_Era.png" style="margin:auto">
