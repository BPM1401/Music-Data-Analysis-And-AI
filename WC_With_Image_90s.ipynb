# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker

from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from wordcloud import WordCloud

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
#bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]

# %%
#Merge BB100 with Features
bb100_f = pd.merge(bb100, features, on='SongID', how='left')

# %%
#Getting Data From The 60's, 70's, 80's, 90's, 00's, 10's
bb60s_f = bb100_f[(bb100_f['WeekID'] >= '1960-1-1') & (bb100_f['WeekID'] < '1970-1-1')]
bb70s_f = bb100_f[(bb100_f['WeekID'] >= '1970-1-1') & (bb100_f['WeekID'] < '1980-1-1')]
bb80s_f = bb100_f[(bb100_f['WeekID'] >= '1980-1-1') & (bb100_f['WeekID'] < '1990-1-1')]
bb90s_f = bb100_f[(bb100_f['WeekID'] >= '1990-1-1') & (bb100_f['WeekID'] < '2000-1-1')]
bb2000s_f = bb100_f[(bb100_f['WeekID'] >= '2000-1-1') & (bb100_f['WeekID'] < '2010-1-1')]
bb2010s_f = bb100_f[(bb100_f['WeekID'] >= '2010-1-1') & (bb100_f['WeekID'] < '2020-1-1')]

# %%
#Convert "Spotify Genres" from Desired Dataframe to a Dict with Frequency Counter & Sorted List

def genre_df_to_dict_counter(df_column):
    
    clean_series = df_column.replace('[]', np.nan).dropna()
    
    new = []
    for item in clean_series:
        for ch in ['\\','`','*','_','{','}','[',']','(',')'
                   ,'>','#','+','.','!','$','\'']:

            if ch in item:
                item = item.replace(ch,'')
        new.append(item)
    
    messy_string = ', '.join(new)
    
    clean_string = [item.strip() for item in messy_string.split(',')]
    dict_counter = {k:clean_string.count(k) for k in set(clean_string)}
    sorted_list = sorted(dict_counter.items(), key=lambda x: x[1], reverse=True)
    
    return dict_counter, sorted_list;

# %%
#Create a WordCloud from Dictionary Frequency


def dict_counter_to_WC(dc_counter, mask=None):
    
    from PIL import Image
    
    # WordCloud Object
    wordcloud = WordCloud(max_words=75, 
                          contour_width=3,
                          max_font_size = 70,
                          width=1000, height=1000,
                          background_color="white",
                          colormap='seismic',
                          prefer_horizontal=0.75,
                          mask=mask
                         )
    
    # Generate a word cloud
    wordcloud.generate_from_frequencies(dc_counter)
    
    #Save it locally
    wordcloud.to_file('90s_WC_with_Image.png')

    # Visualize the word cloud
    # print (wordcloud.words_)
    # print(wordcloud.layout_)
    return wordcloud.to_image()

# %%
#Convert image with no background to RGB format for WordCloud

from PIL import Image
  
def convertImage():
    img = Image.open("Mike_nobg.png")
    img = img.convert("RGBA")
  
    datas = img.getdata()
  
    newData = []
  
    for item in datas:
        if item[0] == 0 and item[1] == 0 and item[2] == 0:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
  
    img.putdata(newData)
    img.save("./New.png", "PNG")
    print("Successful")
  
convertImage()
# Out:
# Successful

# %%
#Use new image as Mask
Mike_mask = np.array(Image.open("New.png"))

# %%
#Check the 255's
Mike_mask[0:3]
# Out:
# array([[[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]]], dtype=uint8)

# %%
dc90s, sl90s = genre_df_to_dict_counter(bb90s_f['spotify_genre'])
#sl90s
dict_counter_to_WC(dc90s,mask=Mike_mask)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408 at 0x7FD7E99F3760>

# %%
sl90s
# Out:
# [('urban contemporary', 10231),
#  ('r&b', 10024),
#  ('dance pop', 9455),
#  ('new jack swing', 8402),
#  ('hip hop', 7946),
#  ('hip pop', 7348),
#  ('pop rock', 6483),
#  ('rock', 6466),
#  ('quiet storm', 6424),
#  ('neo soul', 4972),
#  ('rap', 4868),
#  ('soft rock', 4632),
#  ('pop', 4526),
#  ('new wave pop', 4464),
#  ('mellow gold', 4363),
#  ('gangster rap', 3799),
#  ('album rock', 3214),
#  ('pop rap', 3060),
#  ('hardcore hip hop', 2918),
#  ('post-grunge', 2836),
#  ('permanent wave', 2676),
#  ('country', 2657),
#  ('alternative rock', 2642),
#  ('hip house', 2543),
#  ('europop', 2434),
#  ('hard rock', 2343),
#  ('east coast hip hop', 2298),
#  ('funk', 2292),
#  ('boy band', 2276),
#  ('southern hip hop', 2108),
#  ('lilith', 1833),
#  ('classic rock', 1832),
#  ('girl group', 1731),
#  ('country road', 1728),
#  ('neo mellow', 1697),
#  ('dance rock', 1543),
#  ('glam metal', 1482),
#  ('contemporary country', 1460),
#  ('west coast rap', 1426),
#  ('eurodance', 1421),
#  ('folk', 1364),
#  ('soul', 1338),
#  ('singer-songwriter', 1232),
#  ('freestyle', 1232),
#  ('new romantic', 1226),
#  ('new wave', 1192),
#  ('g funk', 1191),
#  ('canadian pop', 1182),
#  ('adult standards', 1136),
#  ('country dawn', 1053),
#  ('diva house', 1027),
#  ('country rock', 1022),
#  ('folk rock', 978),
#  ('atl hip hop', 969),
#  ('heartland rock', 915),
#  ('alternative metal', 898),
#  ('bubblegum dance', 831),
#  ('motown', 806),
#  ('old school hip hop', 785),
#  ('conscious hip hop', 773),
#  ('reggae fusion', 750),
#  ('queens hip hop', 724),
#  ('art rock', 628),
#  ('metal', 622),
#  ('vocal house', 605),
#  ('disco', 601),
#  ('alternative hip hop', 592),
#  ('synthpop', 565),
#  ('piano rock', 550),
#  ('grunge', 528),
#  ('latin pop', 526),
#  ('modern rock', 524),
#  ('trap', 508),
#  ('dirty south rap', 504),
#  ('deep pop r&b', 492),
#  ('roots rock', 489),
#  ('canadian singer-songwriter', 481),
#  ('glam rock', 444),
#  ('minneapolis sound', 443),
#  ('new jersey rap', 426),
#  ('blues rock', 418),
#  ('miami bass', 396),
#  ('disco house', 383),
#  ('ectofolk', 379),
#  ('indie pop', 376),
#  ('post-disco', 371),
#  ('british soul', 364),
#  ('turntablism', 361),
#  ('britpop', 356),
#  ('funk metal', 351),
#  ('german techno', 350),
#  ('hollywood', 342),
#  ('nu metal', 336),
#  ('chicano rap', 328),
#  ('hyphy', 323),
#  ('funk rock', 316),
#  ('australian pop', 312),
#  ('sleaze rock', 309),
#  ('rap rock', 300),
#  ('canadian country', 295),
#  ('reggae', 290),
#  ('latin', 287),
#  ('classic canadian rock', 262),
#  ('lovers rock', 249),
#  ('new orleans rap', 248),
#  ('christian music', 247),
#  ('christian alternative rock', 247),
#  ('irish rock', 235),
#  ('tropical house', 232),
#  ('post-teen pop', 230),
#  ('yacht rock', 227),
#  ('electric blues', 226),
#  ('roots reggae', 224),
#  ('bronx hip hop', 223),
#  ('symphonic rock', 215),
#  ('electro', 208),
#  ('indie folk', 207),
#  ('folk-pop', 207),
#  ('power pop', 203),
#  ('madchester', 199),
#  ('swedish pop', 195),
#  ('hardcore techno', 192),
#  ('indie rock', 192),
#  ('jazz rap', 189),
#  ('speed metal', 187),
#  ('electronica', 184),
#  ('comic', 179),
#  ('melancholia', 178),
#  ('jam band', 175),
#  ('progressive rock', 174),
#  ('thrash metal', 170),
#  ('deep southern trap', 168),
#  ('big beat', 168),
#  ('norteno', 163),
#  ('alternative pop', 163),
#  ('redneck', 163),
#  ('garage rock', 158),
#  ('house', 157),
#  ('old school dancehall', 156),
#  ('old school thrash', 155),
#  ('mexican pop', 153),
#  ('tropical', 151),
#  ('oklahoma country', 151),
#  ('art pop', 150),
#  ('west coast trap', 150),
#  ('smooth jazz', 149),
#  ('australian rock', 149),
#  ('acoustic pop', 147),
#  ('edm', 146),
#  ('cowpunk', 144),
#  ('chicago rap', 143),
#  ('candy pop', 141),
#  ('modern country rock', 141),
#  ('post-punk', 140),
#  ('dutch pop', 139),
#  ('jangle pop', 137),
#  ('uk americana', 135),
#  ('brill building pop', 134),
#  ('trip hop', 133),
#  ('electronic rock', 132),
#  ('classic soul', 130),
#  ('bubblegum pop', 129),
#  ('anti-folk', 128),
#  ('psychedelic rock', 127),
#  ('alternative dance', 125),
#  ('southern soul', 123),
#  ('nwobhm', 123),
#  ('rock-and-roll', 119),
#  ('harlem hip hop', 119),
#  ('philly rap', 118),
#  ('alaska indie', 117),
#  ('dancehall', 115),
#  ('hi-nrg', 113),
#  ('worship', 112),
#  ('ccm', 112),
#  ('dutch house', 111),
#  ('classic uk pop', 111),
#  ('indietronica', 109),
#  ('reggaeton', 109),
#  ('canadian rock', 108),
#  ('alternative r&b', 108),
#  ('latin hip hop', 107),
#  ('cali rap', 106),
#  ('uk reggae', 105),
#  ('show tunes', 104),
#  ('lo-fi', 104),
#  ('stomp and holler', 102),
#  ('miami hip hop', 101),
#  ('lounge', 97),
#  ('celtic rock', 95),
#  ('industrial rock', 94),
#  ('puerto rican pop', 94),
#  ('classic country pop', 93),
#  ('bachata', 92),
#  ('industrial metal', 91),
#  ('punk', 90),
#  ('lgbtq hip hop', 90),
#  ('outlaw country', 90),
#  ('indie anthem-folk', 90),
#  ('christian rock', 88),
#  ('jazz blues', 88),
#  ('texas country', 86),
#  ('norteno-sax', 85),
#  ('duranguense', 85),
#  ('deep norteno', 85),
#  ('smooth saxophone', 85),
#  ('protopunk', 84),
#  ('scottish rock', 84),
#  ('southern rock', 84),
#  ('new americana', 82),
#  ('seattle indie', 82),
#  ('electropop', 81),
#  ('deep freestyle', 81),
#  ('nashville sound', 79),
#  ('regional mexican pop', 78),
#  ('banda', 78),
#  ('regional mexican', 78),
#  ('indie soul', 76),
#  ('socal pop punk', 75),
#  ('broadway', 75),
#  ('vocal jazz', 74),
#  ('sacramento indie', 70),
#  ('experimental rock', 69),
#  ('acid house', 68),
#  ('canadian indie', 68),
#  ('dub', 67),
#  ('pop punk', 67),
#  ('german metal', 67),
#  ('british invasion', 67),
#  ('german rock', 67),
#  ('new beat', 65),
#  ('popping', 65),
#  ('world worship', 64),
#  ('dream pop', 63),
#  ('crunk', 62),
#  ('country rap', 62),
#  ('industrial', 62),
#  ('arkansas country', 62),
#  ('indie punk', 61),
#  ('rap metal', 60),
#  ('acid jazz', 59),
#  ('ethiopian pop', 58),
#  ('yugoslav rock', 58),
#  ('sevdah', 58),
#  ('memphis soul', 58),
#  ('boston rock', 58),
#  ('turbo folk', 58),
#  ('movie tunes', 57),
#  ('chicago house', 57),
#  ('underground hip hop', 56),
#  ('"childrens music"', 55),
#  ('uk pop', 55),
#  ('escape room', 54),
#  ('pinoy indie', 54),
#  ('bounce', 54),
#  ('emo', 53),
#  ('trap queen', 53),
#  ('midwest emo', 53),
#  ('wrestling', 53),
#  ('small room', 53),
#  ('alternative emo', 53),
#  ('swedish electropop', 52),
#  ('jazz funk', 52),
#  ('philly soul', 52),
#  ('scandipop', 52),
#  ('zolo', 51),
#  ('italo house', 51),
#  ('country gospel', 51),
#  ('noise pop', 50),
#  ('dfw rap', 50),
#  ('atl trap', 50),
#  ('uk post-punk', 50),
#  ('pop reggaeton', 49),
#  ('rockabilly', 48),
#  ('laboratorio', 47),
#  ('deep regional mexican', 47),
#  ('corrido', 47),
#  ('dutch rock', 46),
#  ('antiviral pop', 46),
#  ('new orleans blues', 45),
#  ('rhythm and blues', 45),
#  ('piano blues', 45),
#  ('louisiana blues', 45),
#  ('medieval folk', 44),
#  ('german hard rock', 43),
#  ('wu fam', 43),
#  ('indie poptimism', 43),
#  ('grupera', 42),
#  ('neo-singer-songwriter', 42),
#  ('viral pop', 42),
#  ('christian trap', 41),
#  ('neon pop punk', 41),
#  ('christian hip hop', 41),
#  ('indie r&b', 41),
#  ('rap kreyol', 40),
#  ('doo-wop', 40),
#  ('chamber pop', 40),
#  ('cyberpunk', 39),
#  ('trance', 39),
#  ('deep east coast hip hop', 39),
#  ('rock en espanol', 39),
#  ('melodic hard rock', 39),
#  ('tribal house', 37),
#  ('neo-synthpop', 37),
#  ('desi pop', 36),
#  ('rawstyle', 36),
#  ('desi hip hop', 36),
#  ('gothic rock', 35),
#  ('latin arena pop', 35),
#  ('gospel', 35),
#  ('p funk', 35),
#  ('contemporary gospel', 33),
#  ('emo rap', 33),
#  ('swing', 33),
#  ('canadian contemporary country', 33),
#  ('dark trap', 33),
#  ('underground power pop', 33),
#  ('alternative country', 33),
#  ('alberta country', 33),
#  ('meme rap', 32),
#  ('scottish new wave', 32),
#  ('new jersey indie', 32),
#  ('breakbeat', 32),
#  ('ska', 32),
#  ('riddim', 31),
#  ('southern soul blues', 31),
#  ('nyc pop', 31),
#  ('scottish indie', 31),
#  ('anarcho-punk', 31),
#  ('celtic', 31),
#  ('skate punk', 31),
#  ('shoegaze', 30),
#  ('groove metal', 30),
#  ('big band', 30),
#  ('rock steady', 30),
#  ('boom bap', 30),
#  ('detroit hip hop', 30),
#  ('c86', 29),
#  ('traditional folk', 29),
#  ('electro house', 28),
#  ('australian alternative rock', 28),
#  ('electropowerpop', 28),
#  ('vogue', 28),
#  ('gbvfi', 28),
#  ('big room', 28),
#  ('sunshine pop', 28),
#  ('new age', 28),
#  ('slow core', 28),
#  ('trancecore', 28),
#  ('dubstep', 28),
#  ('oxford indie', 28),
#  ('post-hardcore', 28),
#  ('pub rock', 27),
#  ('parody', 27),
#  ('comedy rock', 27),
#  ('nu jazz', 27),
#  ('northern soul', 27),
#  ('calming instrumental', 26),
#  ('background music', 26),
#  ('focus', 26),
#  ('birmingham metal', 26),
#  ('australian dance', 26),
#  ('lo-fi beats', 26),
#  ('canadian hip hop', 25),
#  ('scorecore', 25),
#  ('strut', 25),
#  ('toronto rap', 25),
#  ('deep house', 25),
#  ('melodic rap', 25),
#  ('trap soul', 25),
#  ('bboy', 24),
#  ('neue deutsche harte', 24),
#  ('australian hip hop', 24),
#  ('electronic trap', 24),
#  ('australian electropop', 24),
#  ('folk metal', 24),
#  ('british blues', 24),
#  ('medieval rock', 24),
#  ('world', 24),
#  ('old school uk hip hop', 23),
#  ('deep progressive trance', 23),
#  ('austindie', 23),
#  ('soca', 23),
#  ('baton rouge rap', 23),
#  ('merseybeat', 22),
#  ('french pop', 22),
#  ('opm', 22),
#  ('korean r&b', 21),
#  ('no wave', 21),
#  ('baroque pop', 21),
#  ('k-pop', 21),
#  ('manchester hip hop', 20),
#  ('jazz boom bap', 20),
#  ('derby indie', 20),
#  ('post-post-hardcore', 20),
#  ('bakersfield sound', 20),
#  ('canadian celtic', 20),
#  ('filter house', 20),
#  ('modern alternative rock', 20),
#  ('contemporary vocal jazz', 20),
#  ('electronicore', 20),
#  ('dayton indie', 20),
#  ('cosmic american', 20),
#  ('liquid funk', 20),
#  ('post-screamo', 20),
#  ('brooklyn indie', 20),
#  ('reggae rock', 20),
#  ('deep contemporary country', 20),
#  ('comic metal', 20),
#  ('okc indie', 20),
#  ('drum and bass', 20),
#  ('deep ragga', 20),
#  ('uk dnb', 20),
#  ('uptempo hardcore', 20),
#  ('vapor soul', 20),
#  ('swedish country', 20),
#  ('deep acoustic pop', 20),
#  ('indie electropop', 20),
#  ('east coast reggae', 20),
#  ('euro hi-nrg', 20),
#  ('shamanic', 20),
#  ('ohio hip hop', 20),
#  ('downtempo', 19),
#  ('italian disco', 19),
#  ('detroit trap', 19),
#  ('boston hip hop', 19),
#  ('dutch indie', 18),
#  ('old school nederhop', 18),
#  ('progressive bluegrass', 18),
#  ('bluegrass', 18),
#  ('progressive metal', 17),
#  ('funana', 17),
#  ('neo classical metal', 17),
#  ('brazilian psychedelic', 17),
#  ('reggaeton flow', 17),
#  ('modern blues', 17),
#  ('salsa', 16),
#  ('modern southern rock', 16),
#  ('modern salsa', 16),
#  ('pinoy praise', 16),
#  ('jazz fusion', 16),
#  ('hyperpop', 15),
#  ('novelty', 15),
#  ('memphis hip hop', 15),
#  ('pixie', 15),
#  ('stoner rock', 15),
#  ('melodic thrash', 15),
#  ('underground rap', 15),
#  ('battle rap', 15),
#  ('modern hard rock', 15),
#  ('grunge pop', 14),
#  ('classic opm', 14),
#  ('filmi', 13),
#  ('alt-idol', 13),
#  ('idol rock', 13),
#  ('talent show', 13),
#  ('j-pixie', 13),
#  ('pop emo', 13),
#  ('sleep', 13),
#  ('environmental', 13),
#  ('deep disco', 12),
#  ('rap latina', 12),
#  ('uk contemporary r&b', 12),
#  ('dark wave', 12),
#  ('comedy', 12),
#  ('new rave', 12),
#  ('experimental pop', 12),
#  ('taiwan singer-songwriter', 11),
#  ('chinese indie', 11),
#  ('classical cello', 11),
#  ('swedish soul', 11),
#  ('bow pop', 11),
#  ('middle earth', 11),
#  ('belgian metal', 11),
#  ('christmas instrumental', 11),
#  ('classic swedish pop', 11),
#  ('taiwan pop', 11),
#  ('jazz saxophone', 11),
#  ('mandopop', 11),
#  ('taiwan indie', 11),
#  ('retro soul', 11),
#  ('scandinavian r&b', 11),
#  ('anthem worship', 10),
#  ('christian pop', 10),
#  ('deep new wave', 10),
#  ('cumbia', 10),
#  ('welsh rock', 10),
#  ('canadian metal', 10),
#  ('progressive psytrance', 10),
#  ('chanson', 10),
#  ('nightcore', 10),
#  ('clean comedy', 10),
#  ('canadian indigenous', 9),
#  ('new jack smooth', 9),
#  ('american folk revival', 9),
#  ('native american', 9),
#  ('texas blues', 9),
#  ('blues', 9),
#  ('indiecoustica', 9),
#  ('nc hip hop', 9),
#  ('deep melodic hard rock', 9),
#  ('dirty texas rap', 8),
#  ('healing', 8),
#  ('ohio indie', 8),
#  ('noise rock', 8),
#  ('freak folk', 8),
#  ('e6fi', 8),
#  ('deep underground hip hop', 8),
#  ('modern bollywood', 8),
#  ('pinoy rock', 8),
#  ('garage psych', 8),
#  ('sufi', 8),
#  ('indian folk', 8),
#  ('focus beats', 7),
#  ('lo-fi brasileiro', 7),
#  ('new orleans funk', 7),
#  ('ska punk', 7),
#  ('ranchera', 7),
#  ('normal indie', 7),
#  ('roots americana', 7),
#  ('lo-fi jazzhop', 7),
#  ('dutch r&b', 7),
#  ('gabba', 7),
#  ('pittsburgh rock', 7),
#  ('second line', 7),
#  ('happy hardcore', 7),
#  ('red dirt', 7),
#  ('ska mexicano', 7),
#  ('detroit house', 6),
#  ('vapor twitch', 6),
#  ('pop edm', 6),
#  ('swedish hard rock', 6),
#  ('chillstep', 6),
#  ('classic russian rock', 6),
#  ('kids dance party', 6),
#  ('deep dubstep', 6),
#  ('catstep', 6),
#  ('norwegian pop', 6),
#  ('icelandic experimental', 5),
#  ('icelandic pop', 5),
#  ('oi', 5),
#  ('deep funk house', 5),
#  ('mollywood', 5),
#  ('metropopolis', 5),
#  ('english indie rock', 5),
#  ('asmr', 5),
#  ('gospel r&b', 5),
#  ('afropop', 4),
#  ('folklore argentino', 4),
#  ('argentine rock', 4),
#  ('sertanejo universitario', 4),
#  ('hands up', 4),
#  ('bedroom pop', 4),
#  ('nueva cancion', 4),
#  ('rock nacional', 4),
#  ('trova', 4),
#  ('hamburg electronic', 4),
#  ('mande pop', 4),
#  ('bubble trance', 4),
#  ('mbalax', 4),
#  ('barbadian pop', 4),
#  ('sertanejo pop', 4),
#  ('cantautor', 4),
#  ('texas punk', 3),
#  ('ethereal wave', 3),
#  ('canadian blues', 3),
#  ('italian pop', 3),
#  ('italo dance', 3),
#  ('dark post-punk', 3),
#  ('folk punk', 3),
#  ('neoclassical', 3),
#  ('ebm', 3),
#  ('new french touch', 3),
#  ('acoustic punk', 3),
#  ('anthem emo', 2),
#  ('fake', 2),
#  ('metallic hardcore', 2),
#  ('cantopop', 2),
#  ('nu gaze', 2),
#  ('c-pop', 2),
#  ('cartoon', 1),
#  ('philly indie', 1)]
