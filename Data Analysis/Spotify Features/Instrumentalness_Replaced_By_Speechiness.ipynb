# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker
from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                         url     WeekID  \
# 18553    http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 103337   http://www.billboard.com/charts/hot-100/1958-08-02 1958-08-02
# 300806  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
# 152154  https://www.billboard.com/charts/hot-100/2021-05-29 2021-05-29
#
#         Week Position                      Song  \
# 18553              63  High School Confidential
# 103337             98           Little Serenade
# 300806             61             Almost Maybes
# 152154             78               White Teeth
#
#                                     Performer  \
# 18553   Jerry Lee Lewis And His Pumping Piano
# 103337                      The Ames Brothers
# 300806                           Jordan Davis
# 152154             YoungBoy Never Broke Again
#
#                                                                SongID  \
# 18553   High School ConfidentialJerry Lee Lewis And His Pumping Piano
# 103337                               Little SerenadeThe Ames Brothers
# 300806                                      Almost MaybesJordan Davis
# 152154                          White TeethYoungBoy Never Broke Again
#
#         Instance  Previous Week Position  Peak Position  Weeks on Chart
# 18553          1                     NaN             63               1
# 103337         1                     NaN             98               1
# 300806         2                    64.0             61              17
# 152154         1                     NaN             78               1

# %%
#Split the Dataframes by Decade from 60s, 70s, 80s, 90s, 2000s, 2010s
bb60s = bb100[(bb100['WeekID'] >= '1960-1-1') & (bb100['WeekID'] < '1970-1-1')]
bb70s = bb100[(bb100['WeekID'] >= '1970-1-1') & (bb100['WeekID'] < '1980-1-1')]
bb80s = bb100[(bb100['WeekID'] >= '1980-1-1') & (bb100['WeekID'] < '1990-1-1')]
bb90s = bb100[(bb100['WeekID'] >= '1990-1-1') & (bb100['WeekID'] < '2000-1-1')]
bb2000s = bb100[(bb100['WeekID'] >= '2000-1-1') & (bb100['WeekID'] < '2010-1-1')]
bb2010s = bb100[(bb100['WeekID'] >= '2010-1-1') & (bb100['WeekID'] < '2020-1-1')]

# %%
#Add Decade Column to Dataframe:
def decade_to_df(df, decade_as_string):
    return df.assign(Decade=decade_as_string)

# %%
#Execute the decade_to_df function on split dataframes:
bb60s = decade_to_df(bb60s, '1960s')
bb70s = decade_to_df(bb70s, '1970s')
bb80s = decade_to_df(bb80s, '1980s')
bb90s = decade_to_df(bb90s, '1990s')
bb2000s = decade_to_df(bb2000s, '2000s')
bb2010s = decade_to_df(bb2010s, '2010s')

# %%
#Stack all dataframes on top of each other
bb_all_decade = pd.concat([bb60s, bb70s, bb80s, bb90s, bb2000s, bb2010s])

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#Merge bb60s with features and check distribution of 'instrumentalness'
bb60s_features = pd.merge(bb60s, features, on='SongID', how='left')
sns.kdeplot(data=bb60s_features, x='instrumentalness', fill=True, alpha=1);

# %%
#Merge bb70s with features and check distribution of 'instrumentalness'
bb70s_features = pd.merge(bb70s, features, on='SongID', how='left')
sns.kdeplot(data=bb70s_features, x='instrumentalness', fill=True, alpha=1);

# %%
#Merge bb80s with features and check distribution of 'instrumentalness'
bb80s_features = pd.merge(bb80s, features, on='SongID', how='left')
sns.kdeplot(data=bb80s_features, x='instrumentalness', fill=True, alpha=1);

# %%
#Merge bb90s with features and check distribution of 'instrumentalness'
bb90s_features = pd.merge(bb90s, features, on='SongID', how='left')
sns.kdeplot(data=bb90s_features, x='instrumentalness', fill=True, alpha=1);

# %%
#Merge bb2000s with features and check distribution of 'instrumentalness'
bb2000s_features = pd.merge(bb2000s, features, on='SongID', how='left')
sns.kdeplot(data=bb2000s_features, x='instrumentalness', fill=True, alpha=1);

# %%
#Merge bb2010s with features and check distribution of 'instrumentalness'
bb2010s_features = pd.merge(bb2010s, features, on='SongID', how='left')
sns.kdeplot(data=bb2010s_features, x='instrumentalness', fill=True, alpha=1);

# %%
fig = sns.kdeplot(data=bb60s_features, x='instrumentalness', shade=True, color='r')
fig = sns.kdeplot(data=bb70s_features, x='instrumentalness', shade=True, color='b');

# %%
bb_all_dec_feat = pd.merge(bb_all_decade, features, on='SongID', how='left')
bb_all_dec_feat.describe()
# Out:
#        Week Position       Instance  Previous Week Position  Peak Position  \
# count  315456.000000  315456.000000           285467.000000  315456.000000
# mean       50.434102       1.069747               47.617465      41.387395
# std        28.871837       0.327853               28.076176      29.534372
# min         1.000000       1.000000                1.000000       1.000000
# 25%        25.000000       1.000000               23.000000      14.000000
# 50%        50.000000       1.000000               47.000000      39.000000
# 75%        75.000000       1.000000               72.000000      66.000000
# max       100.000000       9.000000              100.000000     100.000000
#
#        Weeks on Chart  spotify_track_duration_ms  spotify_track_explicit  \
# count   315456.000000               2.766190e+05           276619.000000
# mean         9.191773               2.308336e+05                0.112816
# std          7.573105               6.457150e+04                0.316368
# min          1.000000               2.968800e+04                0.000000
# 25%          4.000000               1.919860e+05                0.000000
# 50%          7.000000               2.263330e+05                0.000000
# 75%         13.000000               2.605740e+05                0.000000
# max         87.000000               3.079157e+06                1.000000
#
#         danceability         energy            key       loudness  \
# count  276097.000000  276097.000000  276097.000000  276097.000000
# mean        0.614380       0.634074       5.255776      -8.335211
# std         0.149584       0.192598       3.565160       3.541917
# min         0.103000       0.000581       0.000000     -28.030000
# 25%         0.517000       0.496000       2.000000     -10.667000
# 50%         0.622000       0.652000       5.000000      -7.758000
# 75%         0.721000       0.789000       8.000000      -5.582000
# max         0.988000       0.997000      11.000000       2.291000
#
#                 mode    speechiness   acousticness  instrumentalness  \
# count  276097.000000  276097.000000  276097.000000     276097.000000
# mean        0.715998       0.071321       0.252920          0.027741
# std         0.450938       0.078149       0.260286          0.123570
# min         0.000000       0.022000       0.000003          0.000000
# 25%         0.000000       0.032100       0.037400          0.000000
# 50%         1.000000       0.041300       0.153000          0.000004
# 75%         1.000000       0.067100       0.411000          0.000380
# max         1.000000       0.951000       0.991000          0.982000
#
#             liveness        valence          tempo  time_signature  \
# count  276097.000000  276097.000000  276097.000000   276097.000000
# mean        0.185188       0.600173     120.099230        3.951499
# std         0.154318       0.235445      27.667887        0.273837
# min         0.013000       0.034900      35.716000        0.000000
# 25%         0.087800       0.418000      99.150000        4.000000
# 50%         0.126000       0.619000     118.714000        4.000000
# 75%         0.240000       0.796000     135.938000        4.000000
# max         0.999000       0.991000     241.009000        5.000000
#
#        spotify_track_popularity
# count             276619.000000
# mean                  47.869337
# std                   21.081375
# min                    0.000000
# 25%                   33.000000
# 50%                   50.000000
# 75%                   64.000000
# max                  100.000000

# %%
bb_all_dec_feat.sort_values(by='instrumentalness', ascending=False).groupby('Decade').mean()
# Out:
#         Week Position  Instance  Previous Week Position  Peak Position  \
# Decade
# 1960s       50.505485  1.033813               48.051657      46.778322
# 1970s       50.500690  1.019023               47.955961      44.973238
# 1980s       50.495308  1.010208               46.762318      38.350021
# 1990s       50.495652  1.014013               48.005063      38.619349
# 2000s       50.500623  1.073160               48.112697      40.145323
# 2010s       50.120825  1.259754               46.856782      39.532715
#
#         Weeks on Chart  spotify_track_duration_ms  spotify_track_explicit  \
# Decade
# 1960s         5.544602              165657.253666                0.000355
# 1970s         7.041475              234634.079562                0.000845
# 1980s         8.464186              256779.202899                0.003020
# 1990s        10.341434              264818.484037                0.097975
# 2000s        11.258405              239768.550181                0.207018
# 2010s        12.364217              220575.610385                0.319800
#
#         danceability    energy       key   loudness      mode  speechiness  \
# Decade
# 1960s       0.534563  0.515995  5.135581 -10.380635  0.835894     0.049199
# 1970s       0.578622  0.581086  5.147471 -10.443024  0.756195     0.052244
# 1980s       0.629781  0.649123  5.288762  -9.839070  0.705490     0.046358
# 1990s       0.650911  0.646782  5.424418  -8.549515  0.659814     0.074395
# 2000s       0.632925  0.709780  5.253496  -5.726375  0.674973     0.097080
# 2010s       0.647745  0.679556  5.276235  -5.833401  0.679670     0.100735
#
#         acousticness  instrumentalness  liveness   valence       tempo  \
# Decade
# 1960s       0.524225          0.056394  0.215586  0.667754  119.687649
# 1970s       0.336621          0.046150  0.188122  0.665430  119.353487
# 1980s       0.208785          0.026678  0.177853  0.655414  121.080617
# 1990s       0.176666          0.029460  0.177769  0.576200  117.513200
# 2000s       0.148563          0.007860  0.179232  0.556140  120.086203
# 2010s       0.162962          0.007084  0.176312  0.502580  122.386642
#
#         time_signature  spotify_track_popularity
# Decade
# 1960s         3.852160                 28.389440
# 1970s         3.943839                 38.260402
# 1980s         3.976118                 43.727549
# 1990s         3.962462                 46.263627
# 2000s         3.974753                 56.316749
# 2010s         3.985901                 68.885148

# %%
bb_all_dec_feat[['Decade','instrumentalness']].dropna().groupby('Decade').mean().plot();

# %%
bb_all_dec_feat[['Decade','speechiness']].dropna().groupby('Decade').mean().plot();

# %%
sns.kdeplot(data = bb_all_dec_feat.dropna(), x='WeekID', y='speechiness', cmap='Reds', shade=True)
plt.ylim([0,0.4]);

# %%
sns.kdeplot(data = bb_all_dec_feat, x='WeekID', y='instrumentalness', cmap='Reds', shade=True)
plt.ylim(0,0.25);

# %%
#Strip plot for Instrumentalness to show how it has gradually decreased over time.....
sns.stripplot(data=bb_all_dec_feat, x='Decade', y='instrumentalness', jitter=0.25, size=1.5)
plt.title('Gradual Decline Of Instrumentalness', fontsize=20)
plt.ylabel('Instrumentalness', fontsize=16)
plt.xlabel('Decade', fontsize=15)
plt.figure(figsize=(10,10));

# %%
#Strip plot for Instrumentalness to show how it has gradually decreased over time.....

sns.stripplot(data=bb_all_dec_feat, x='Decade', y='instrumentalness', jitter=0.25, size=1.5)
plt.title('Gradual Decline Of Instrumentalness', fontsize=24, color='black')
plt.ylabel('Instrumentalness', fontsize=20, color='black')
plt.xlabel('Decade', fontsize=20, color='black')
sns.set(rc = {'figure.figsize':(12,8)})
plt.savefig('Instrumental_Decline.png');

# %%
#Remvoing Nan does not make difference....
sns.stripplot(data=bb_all_dec_feat.dropna(subset=['instrumentalness']), x='Decade', y='instrumentalness', jitter=0.25, size=1.5);

# %%
bb_all_dec_feat.count()
# Out:
# url                          315456
# WeekID                       315456
# Week Position                315456
# Song_x                       315456
# Performer_x                  315456
# SongID                       315456
# Instance                     315456
# Previous Week Position       285467
# Peak Position                315456
# Weeks on Chart               315456
# Decade                       315456
# Performer_y                  315420
# Song_y                       315420
# spotify_genre                304393
# spotify_track_id             276619
# spotify_track_preview_url    163669
# spotify_track_duration_ms    276619
# spotify_track_explicit       276619
# spotify_track_album          276557
# danceability                 276097
# energy                       276097
# key                          276097
# loudness                     276097
# mode                         276097
# speechiness                  276097
# acousticness                 276097
# instrumentalness             276097
# liveness                     276097
# valence                      276097
# tempo                        276097
# time_signature               276097
# spotify_track_popularity     276619
# dtype: int64

# %%
no_song_dup = bb_all_dec_feat.drop_duplicates(subset='SongID')
no_song_dup
# Out:
#                                                         url     WeekID  \
# 0        http://www.billboard.com/charts/hot-100/1965-07-17 1965-07-17
# 8        http://www.billboard.com/charts/hot-100/1960-01-02 1960-01-02
# 9        http://www.billboard.com/charts/hot-100/1960-02-20 1960-02-20
# 10       http://www.billboard.com/charts/hot-100/1960-08-20 1960-08-20
# 11       http://www.billboard.com/charts/hot-100/1961-11-18 1961-11-18
# ...                                                     ...        ...
# 306453   http://www.billboard.com/charts/hot-100/2011-12-24 2011-12-24
# 306471   http://www.billboard.com/charts/hot-100/2015-04-11 2015-04-11
# 306492   http://www.billboard.com/charts/hot-100/2011-03-19 2011-03-19
# 307650  https://www.billboard.com/charts/hot-100/2019-01-05 2019-01-05
# 309192  https://www.billboard.com/charts/hot-100/2017-11-04 2017-11-04
#
#         Week Position                     Song_x                Performer_x  \
# 0                  34     Don't Just Stand There                 Patty Duke
# 8                  68                 Crazy Arms                Bob Beckham
# 9                  68                  O Dio Mio                    Annette
# 10                 68                 Delia Gone                  Pat Boone
# 11                 68  Peppermint Twist - Part I  Joey Dee & the Starliters
# ...               ...                        ...                        ...
# 306453             91              You Gonna Fly                Keith Urban
# 306471             99       You Know You Like It     DJ Snake & AlunaGeorge
# 306492             80                    You Lie             The Band Perry
# 307650             45            Run Rudolph Run                Chuck Berry
# 309192             40                   Do Re Mi                  blackbear
#
#                                                     SongID  Instance  \
# 0                         Don't Just Stand TherePatty Duke         1
# 8                                    Crazy ArmsBob Beckham         1
# 9                                         O Dio MioAnnette         1
# 10                                     Delia GonePat Boone         1
# 11      Peppermint Twist - Part IJoey Dee & the Starliters         1
# ...                                                    ...       ...
# 306453                            You Gonna FlyKeith Urban         1
# 306471          You Know You Like ItDJ Snake & AlunaGeorge         1
# 306492                               You LieThe Band Perry         1
# 307650                          Run Rudolph RunChuck Berry         2
# 309192                                   Do Re Miblackbear         2
#
#         Previous Week Position  Peak Position  Weeks on Chart Decade  \
# 0                         45.0             34               4  1960s
# 8                          NaN             68               1  1960s
# 9                          NaN             68               1  1960s
# 10                         NaN             68               1  1960s
# 11                         NaN             68               1  1960s
# ...                        ...            ...             ...    ...
# 306453                     NaN             91               1  2010s
# 306471                     NaN             99               1  2010s
# 306492                     NaN             80               1  2010s
# 307650                     NaN             45               4  2010s
# 309192                    45.0             40              19  2010s
#
#                       Performer_y                     Song_y  \
# 0                      Patty Duke     Don't Just Stand There
# 8                     Bob Beckham                 Crazy Arms
# 9                         Annette                  O Dio Mio
# 10                      Pat Boone                 Delia Gone
# 11      Joey Dee & the Starliters  Peppermint Twist - Part I
# ...                           ...                        ...
# 306453                Keith Urban              You Gonna Fly
# 306471     DJ Snake & AlunaGeorge       You Know You Like It
# 306492             The Band Perry                    You Lie
# 307650                Chuck Berry            Run Rudolph Run
# 309192                        NaN                        NaN
#
#                                                                                                spotify_genre  \
# 0                                                                                   ['deep adult standards']
# 8                                                                                                        NaN
# 9                                                                  ['latin christian', 'mariachi cristiano']
# 10      ['adult standards', 'brill building pop', 'easy listening', 'lounge', 'rock-and-roll', 'rockabilly']
# 11                                                                                ['australian talent show']
# ...                                                                                                      ...
# 306453                             ['australian country', 'contemporary country', 'country', 'country road']
# 306471                                                                                   ['electronic trap']
# 306492            ['contemporary country', 'country', 'country dawn', 'country road', 'modern country rock']
# 307650                         ['blues rock', 'classic rock', 'rock', 'rock-and-roll', 'rockabilly', 'soul']
# 309192                                                                                                   NaN
#
#               spotify_track_id  \
# 0       1YhNCQ3XOdTCZgubfX8PgB
# 8                          NaN
# 9       6kFmfcqpy1ok5wfls2yCtZ
# 10                         NaN
# 11      3RW8ZidI0OE9BnzZeNoNQv
# ...                        ...
# 306453  5B25Jpgu62IX8w1YtLibuA
# 306471  57kR5SniQIbsbVoIjjOUDa
# 306492  462tT5pBVstoLcOSJsBBKw
# 307650  2pnPe4pJtq7689i5ydzvJJ
# 309192                     NaN
#
#                                                                                           spotify_track_preview_url  \
# 0                                                                                                               NaN
# 8                                                                                                               NaN
# 9                                                                                                               NaN
# 10                                                                                                              NaN
# 11      https://p.scdn.co/mp3-preview/ec534a2d4b6dbff7b3a2c5279865072a40d09469?cid=b8d3901151d34489a160e3cf0ab1fa94
# ...                                                                                                             ...
# 306453                                                                                                          NaN
# 306471                                                                                                          NaN
# 306492                                                                                                          NaN
# 307650                                                                                                          NaN
# 309192                                                                                                          NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 0                        163160.0                     0.0
# 8                             NaN                     NaN
# 9                        171426.0                     0.0
# 10                            NaN                     NaN
# 11                       259266.0                     0.0
# ...                           ...                     ...
# 306453                   216866.0                     0.0
# 306471                   247266.0                     0.0
# 306492                   214733.0                     0.0
# 307650                   165733.0                     0.0
# 309192                        NaN                     NaN
#
#                                             spotify_track_album  danceability  \
# 0       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 8                                                           NaN           NaN
# 9                                                  Italiannette         0.378
# 10                                                          NaN           NaN
# 11      Doin' the Twist at the Peppermint Lounge. Recorded Live         0.326
# ...                                                         ...           ...
# 306453                              Get Closer (Deluxe Version)         0.457
# 306471                                     You Know You Like It         0.426
# 306492                                           The Band Perry         0.521
# 307650                                   Rock 'N' Roll Rarities         0.688
# 309192                                                      NaN           NaN
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 0        0.256  7.0   -15.044   1.0       0.0298        0.6100
# 8          NaN  NaN       NaN   NaN          NaN           NaN
# 9        0.439  5.0    -7.935   1.0       0.0303        0.2370
# 10         NaN  NaN       NaN   NaN          NaN           NaN
# 11       0.816  8.0   -14.825   1.0       0.0527        0.8810
# ...        ...  ...       ...   ...          ...           ...
# 306453   0.846  4.0    -8.547   1.0       0.0477        0.0598
# 306471   0.722  5.0    -5.369   0.0       0.1960        0.0113
# 306492   0.656  6.0    -5.015   1.0       0.0289        0.3870
# 307650   0.711  7.0   -10.453   0.0       0.0832        0.7880
# 309192     NaN  NaN       NaN   NaN          NaN           NaN
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000077    0.1000    0.568   82.331             3.0
# 8                    NaN       NaN      NaN      NaN             NaN
# 9               0.000008    0.0980    0.422  115.626             4.0
# 10                   NaN       NaN      NaN      NaN             NaN
# 11              0.326000    0.1850    0.826  147.213             4.0
# ...                  ...       ...      ...      ...             ...
# 306453          0.000000    0.3400    0.851  177.353             4.0
# 306471          0.000001    0.2620    0.250  196.133             4.0
# 306492          0.000000    0.1430    0.598  170.939             4.0
# 307650          0.000026    0.0683    0.935  152.277             4.0
# 309192               NaN       NaN      NaN      NaN             NaN
#
#         spotify_track_popularity
# 0                           21.0
# 8                            NaN
# 9                           11.0
# 10                           NaN
# 11                           0.0
# ...                          ...
# 306453                      43.0
# 306471                      71.0
# 306492                      50.0
# 307650                      85.0
# 309192                       NaN
#
# [27655 rows x 32 columns]

# %%
#Instrumentalness is replaced by "Speechiness" ever so gradually over time.....
sns.stripplot(data=bb_all_dec_feat, x='Decade', y='speechiness', jitter=0.25, size=1.5);
plt.title('Lyrics Replace Instruments', fontsize=24, color='black')
plt.ylabel('Speechiness', fontsize=20, color='black')
plt.xlabel('Decade', fontsize=20, color='black')
sns.set(rc = {'figure.figsize':(12,8)})
plt.savefig('Speechiness_Incline.png');

# %%
sns.stripplot(data=bb_all_dec_feat.dropna(subset=['speechiness']), x='Decade', y='speechiness', jitter=0.25, size=1.5);

# %%
##Good idea to go to WordCloud for 80s vs 90s at this point.....guitar to mike shape?

# %%
#Top 10 speechy performers by decade does not illustrate clear winner.....

# %%
speechy = bb_all_dec_feat[['Performer_x','speechiness']].dropna().groupby('Performer_x').mean().sort_values(by='speechiness', ascending=False).reset_index()

# %%
speechy[speechy['Performer_x']=='Ed Sheeran']
# Out:
#      Performer_x  speechiness
# 3581  Ed Sheeran     0.052752

# %%
speechy_top10 = speechy.head(10)
speechy_top10
# Out:
#                                             Performer_x  speechiness
# 0                   Chris Young Duet With Cassadee Pope     0.951000
# 1                                     Hudson and Landry     0.916300
# 2                                         Charlie Drake     0.846000
# 3                                          Steve Martin     0.763714
# 4                                   Bob & Doug McKenzie     0.728000
# 5              D'Angelo Featuring Method Man And Redman     0.628000
# 6                                       Wink Martindale     0.618000
# 7                         YG Featuring Drake & Kamaiyah     0.594000
# 8  Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown     0.592000
# 9                          Lil Baby Featuring Meek Mill     0.589000

# %%
speechy_top10_dec = pd.merge(speechy_top10, bb_all_dec_feat, on='Performer_x', how='left').drop_duplicates(subset='Performer_x')

# %%
speechy_top10_dec[['Performer_x', 'speechiness_x', 'Decade']]
# Out:
#                                               Performer_x  speechiness_x  \
# 0                     Chris Young Duet With Cassadee Pope       0.951000
# 20                                      Hudson and Landry       0.916300
# 40                                          Charlie Drake       0.846000
# 52                                           Steve Martin       0.763714
# 59                                    Bob & Doug McKenzie       0.728000
# 73               D'Angelo Featuring Method Man And Redman       0.628000
# 78                                        Wink Martindale       0.618000
# 81                          YG Featuring Drake & Kamaiyah       0.594000
# 99   Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown       0.592000
# 124                          Lil Baby Featuring Meek Mill       0.589000
#
#     Decade
# 0    2010s
# 20   1970s
# 40   1960s
# 52   1970s
# 59   1980s
# 73   1990s
# 78   1960s
# 81   2010s
# 99   2010s
# 124  2010s

# %%
sns.violinplot(x='Decade', y='instrumentalness', data=bb_all_dec_feat);

# %%
bb_all_dec_feat.speechiness.hist();

# %%
bb_all_dec_feat.danceability.hist();

# %%
sns.kdeplot(data=bb_all_dec_feat, x='danceability', hue='Decade', fill=True);

# %%
bb_all_dec_feat.acousticness.hist();

# %%
bb_all_dec_feat.valence.hist();

# %%
sns.histplot(data=bb_all_dec_feat, x='valence', y='acousticness', cbar=True);

# %%
bb_all_dec_feat.hist();

# %%
bb_all_dec_feat
# Out:
#                                                         url     WeekID  \
# 0        http://www.billboard.com/charts/hot-100/1965-07-17 1965-07-17
# 1        http://www.billboard.com/charts/hot-100/1965-07-24 1965-07-24
# 2        http://www.billboard.com/charts/hot-100/1965-07-31 1965-07-31
# 3        http://www.billboard.com/charts/hot-100/1965-08-07 1965-08-07
# 4        http://www.billboard.com/charts/hot-100/1965-08-14 1965-08-14
# ...                                                     ...        ...
# 315451   http://www.billboard.com/charts/hot-100/2011-08-20 2011-08-20
# 315452   http://www.billboard.com/charts/hot-100/2017-10-14 2017-10-14
# 315453   http://www.billboard.com/charts/hot-100/2010-05-15 2010-05-15
# 315454  https://www.billboard.com/charts/hot-100/2018-05-19 2018-05-19
# 315455  https://www.billboard.com/charts/hot-100/2018-10-20 2018-10-20
#
#         Week Position                         Song_x  \
# 0                  34         Don't Just Stand There
# 1                  22         Don't Just Stand There
# 2                  14         Don't Just Stand There
# 3                  10         Don't Just Stand There
# 4                   8         Don't Just Stand There
# ...               ...                            ...
# 315451             21                      Knee Deep
# 315452             21                       Mi Gente
# 315453             21  I Made It (Cash Money Heroes)
# 315454             21                        Friends
# 315455             22                 God Is A Woman
#
#                                                   Performer_x  \
# 0                                                  Patty Duke
# 1                                                  Patty Duke
# 2                                                  Patty Duke
# 3                                                  Patty Duke
# 4                                                  Patty Duke
# ...                                                       ...
# 315451                 Zac Brown Band Featuring Jimmy Buffett
# 315452             J Balvin & Willy William Featuring Beyonce
# 315453  Kevin Rudolf Featuring Birdman, Jay Sean, & Lil Wayne
# 315454                                Marshmello & Anne-Marie
# 315455                                          Ariana Grande
#
#                                                                                     SongID  \
# 0                                                         Don't Just Stand TherePatty Duke
# 1                                                         Don't Just Stand TherePatty Duke
# 2                                                         Don't Just Stand TherePatty Duke
# 3                                                         Don't Just Stand TherePatty Duke
# 4                                                         Don't Just Stand TherePatty Duke
# ...                                                                                    ...
# 315451                                     Knee DeepZac Brown Band Featuring Jimmy Buffett
# 315452                                  Mi GenteJ Balvin & Willy William Featuring Beyonce
# 315453  I Made It (Cash Money Heroes)Kevin Rudolf Featuring Birdman, Jay Sean, & Lil Wayne
# 315454                                                      FriendsMarshmello & Anne-Marie
# 315455                                                         God Is A WomanAriana Grande
#
#         Instance  Previous Week Position  Peak Position  Weeks on Chart  \
# 0              1                    45.0             34               4
# 1              1                    34.0             22               5
# 2              1                    22.0             14               6
# 3              1                    14.0             10               7
# 4              1                    10.0              8               8
# ...          ...                     ...            ...             ...
# 315451         1                    19.0             18              13
# 315452         1                    19.0             19              13
# 315453         1                    23.0             21              13
# 315454         1                    25.0             21              13
# 315455         1                    21.0              8              13
#
#        Decade                                            Performer_y  \
# 0       1960s                                             Patty Duke
# 1       1960s                                             Patty Duke
# 2       1960s                                             Patty Duke
# 3       1960s                                             Patty Duke
# 4       1960s                                             Patty Duke
# ...       ...                                                    ...
# 315451  2010s                 Zac Brown Band Featuring Jimmy Buffett
# 315452  2010s             J Balvin & Willy William Featuring Beyonce
# 315453  2010s  Kevin Rudolf Featuring Birdman, Jay Sean, & Lil Wayne
# 315454  2010s                                Marshmello & Anne-Marie
# 315455  2010s                                          Ariana Grande
#
#                                Song_y  \
# 0              Don't Just Stand There
# 1              Don't Just Stand There
# 2              Don't Just Stand There
# 3              Don't Just Stand There
# 4              Don't Just Stand There
# ...                               ...
# 315451                      Knee Deep
# 315452                       Mi Gente
# 315453  I Made It (Cash Money Heroes)
# 315454                        Friends
# 315455                 God Is A Woman
#
#                                                                      spotify_genre  \
# 0                                                         ['deep adult standards']
# 1                                                         ['deep adult standards']
# 2                                                         ['deep adult standards']
# 3                                                         ['deep adult standards']
# 4                                                         ['deep adult standards']
# ...                                                                            ...
# 315451  ['contemporary country', 'country', 'country road', 'modern country rock']
# 315452                                                      ['latin', 'reggaeton']
# 315453                                                    ['dance pop', 'pop rap']
# 315454                                    ['brostep', 'progressive electro house']
# 315455                                       ['dance pop', 'pop', 'post-teen pop']
#
#               spotify_track_id  \
# 0       1YhNCQ3XOdTCZgubfX8PgB
# 1       1YhNCQ3XOdTCZgubfX8PgB
# 2       1YhNCQ3XOdTCZgubfX8PgB
# 3       1YhNCQ3XOdTCZgubfX8PgB
# 4       1YhNCQ3XOdTCZgubfX8PgB
# ...                        ...
# 315451  1yEwEiTpsaPhQi9lb5EVV4
# 315452  4ipnJyDU3Lq15qBAYNqlqK
# 315453  6H2wnX7ytNeCKERIVqCwgs
# 315454  08bNPGLD8AhKpnnERrAc6G
# 315455  67kQ3UW7saqCFqB54BVKKI
#
#                                                                                           spotify_track_preview_url  \
# 0                                                                                                               NaN
# 1                                                                                                               NaN
# 2                                                                                                               NaN
# 3                                                                                                               NaN
# 4                                                                                                               NaN
# ...                                                                                                             ...
# 315451  https://p.scdn.co/mp3-preview/f6e8c491a6b3c9fe1de5fb1aefa7f1c3c297cfab?cid=b8d3901151d34489a160e3cf0ab1fa94
# 315452                                                                                                          NaN
# 315453                                                                                                          NaN
# 315454  https://p.scdn.co/mp3-preview/99b833cf96a8b56040859443d8688a2e322c6667?cid=b8d3901151d34489a160e3cf0ab1fa94
# 315455                                                                                                          NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 0                        163160.0                     0.0
# 1                        163160.0                     0.0
# 2                        163160.0                     0.0
# 3                        163160.0                     0.0
# 4                        163160.0                     0.0
# ...                           ...                     ...
# 315451                   203173.0                     0.0
# 315452                   189440.0                     0.0
# 315453                   249546.0                     1.0
# 315454                   202620.0                     1.0
# 315455                   213068.0                     0.0
#
#                                             spotify_track_album  danceability  \
# 0       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 1       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 2       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 3       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 4       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# ...                                                         ...           ...
# 315451                           You Get What You Give (Deluxe)         0.715
# 315452                                                 Mi Gente         0.774
# 315453                                               To The Sky         0.400
# 315454                                                  FRIENDS         0.626
# 315455                                 k bye for now (swt live)         0.602
#
#         energy   key  loudness  mode  speechiness  acousticness  \
# 0        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 1        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 2        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 3        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 4        0.256   7.0   -15.044   1.0       0.0298        0.6100
# ...        ...   ...       ...   ...          ...           ...
# 315451   0.584   8.0    -8.231   1.0       0.0296        0.4320
# 315452   0.687  11.0    -4.818   0.0       0.0584        0.0179
# 315453   0.944   7.0    -2.902   1.0       0.1840        0.0481
# 315454   0.880   9.0    -2.384   0.0       0.0504        0.2050
# 315455   0.658   1.0    -5.934   1.0       0.0558        0.0233
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000077     0.100    0.568   82.331             3.0
# 1               0.000077     0.100    0.568   82.331             3.0
# 2               0.000077     0.100    0.568   82.331             3.0
# 3               0.000077     0.100    0.568   82.331             3.0
# 4               0.000077     0.100    0.568   82.331             3.0
# ...                  ...       ...      ...      ...             ...
# 315451          0.000001     0.095    0.610   90.987             4.0
# 315452          0.000012     0.128    0.308  104.959             4.0
# 315453          0.000000     0.345    0.574  124.224             5.0
# 315454          0.000000     0.128    0.534   95.079             4.0
# 315455          0.000060     0.237    0.268  145.031             4.0
#
#         spotify_track_popularity
# 0                           21.0
# 1                           21.0
# 2                           21.0
# 3                           21.0
# 4                           21.0
# ...                          ...
# 315451                      70.0
# 315452                      74.0
# 315453                      55.0
# 315454                      85.0
# 315455                      62.0
#
# [315456 rows x 32 columns]
