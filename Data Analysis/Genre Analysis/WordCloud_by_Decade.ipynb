# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker

from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from wordcloud import WordCloud

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
#bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]

# %%
#Merge BB100 with Features
bb100_f = pd.merge(bb100, features, on='SongID', how='left')

# %%
#Getting Data From The 60's, 70's, 80's, 90's, 00's, 10's
bb60s_f = bb100_f[(bb100_f['WeekID'] >= '1960-1-1') & (bb100_f['WeekID'] < '1970-1-1')]
bb70s_f = bb100_f[(bb100_f['WeekID'] >= '1970-1-1') & (bb100_f['WeekID'] < '1980-1-1')]
bb80s_f = bb100_f[(bb100_f['WeekID'] >= '1980-1-1') & (bb100_f['WeekID'] < '1990-1-1')]
bb90s_f = bb100_f[(bb100_f['WeekID'] >= '1990-1-1') & (bb100_f['WeekID'] < '2000-1-1')]
bb2000s_f = bb100_f[(bb100_f['WeekID'] >= '2000-1-1') & (bb100_f['WeekID'] < '2010-1-1')]
bb2010s_f = bb100_f[(bb100_f['WeekID'] >= '2010-1-1') & (bb100_f['WeekID'] < '2020-1-1')]

# %%
#Splitting 3-ways:
bb67 = bb100_f[(bb100_f['WeekID'] >= '1960-1-1') & (bb100_f['WeekID'] < '1980-1-1')]
bb89 = bb100_f[(bb100_f['WeekID'] >= '1980-1-1') & (bb100_f['WeekID'] < '2000-1-1')]
bb01 = bb100_f[(bb100_f['WeekID'] >= '2000-1-1') & (bb100_f['WeekID'] < '2020-1-1')]

# %%
#Cross Check one results, the 60s:
bb60s_f.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]
# Out:
#                                                        url     WeekID  \
# 243811  http://www.billboard.com/charts/hot-100/1960-01-02 1960-01-02
# 251352  http://www.billboard.com/charts/hot-100/1960-01-02 1960-01-02
# 229133  http://www.billboard.com/charts/hot-100/1969-12-27 1969-12-27
# 210943  http://www.billboard.com/charts/hot-100/1969-12-27 1969-12-27
#
#         Week Position              Song_x                      Performer_x  \
# 243811             24  First Name Initial      Annette With The Afterbeats
# 251352             10       Go, Jimmy, Go                    Jimmy Clanton
# 229133             11     Midnight Cowboy               Ferrante & Teicher
# 210943             61            Midnight  Dennis Yost And The Classics IV
#
#                                                SongID  Instance  \
# 243811  First Name InitialAnnette With The Afterbeats         1
# 251352                     Go, Jimmy, GoJimmy Clanton         1
# 229133              Midnight CowboyFerrante & Teicher         1
# 210943        MidnightDennis Yost And The Classics IV         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  \
# 243811                    29.0             24              11
# 251352                    19.0             10               5
# 229133                    15.0             11               9
# 210943                    58.0             58               7
#
#                             Performer_y              Song_y  \
# 243811      Annette With The Afterbeats  First Name Initial
# 251352                    Jimmy Clanton       Go, Jimmy, Go
# 229133               Ferrante & Teicher     Midnight Cowboy
# 210943  Dennis Yost And The Classics IV            Midnight
#
#                                                                                                       spotify_genre  \
# 243811                                                                                                          NaN
# 251352  ['brill building pop', 'deep adult standards', 'doo-wop', 'rhythm and blues', 'rock-and-roll', 'swamp pop']
# 229133                                                   ['adult standards', 'easy listening', 'exotica', 'lounge']
# 210943                                                                                                           []
#
#               spotify_track_id  \
# 243811                     NaN
# 251352  15mwNCoUIJJ1dvtNeSbY7J
# 229133                     NaN
# 210943  1iwcvFex3aq5mTosFFV2RG
#
#                                                                                           spotify_track_preview_url  \
# 243811                                                                                                          NaN
# 251352  https://p.scdn.co/mp3-preview/f369dc96b1aacff6f768e1fd53308a48c50a39f2?cid=b8d3901151d34489a160e3cf0ab1fa94
# 229133                                                                                                          NaN
# 210943                                                                                                          NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 243811                        NaN                     NaN
# 251352                   126426.0                     0.0
# 229133                        NaN                     NaN
# 210943                   174000.0                     0.0
#
#                                 spotify_track_album  danceability  energy  \
# 243811                                          NaN           NaN     NaN
# 251352        Pop Megahits Of The 1950's - Volume 2         0.684   0.374
# 229133                                          NaN           NaN     NaN
# 210943  The Best Of Dennis Yost And The Classics IV         0.330   0.318
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 243811  NaN       NaN   NaN          NaN           NaN               NaN
# 251352  0.0   -12.037   1.0       0.0358         0.435          0.000000
# 229133  NaN       NaN   NaN          NaN           NaN               NaN
# 210943  9.0   -10.777   0.0       0.0324         0.760          0.000001
#
#         liveness  valence    tempo  time_signature  spotify_track_popularity
# 243811       NaN      NaN      NaN             NaN                       NaN
# 251352     0.131    0.846  142.815             4.0                      14.0
# 229133       NaN      NaN      NaN             NaN                       NaN
# 210943     0.172    0.467  121.306             4.0                       1.0

# %%
#Convert "Spotify Genres" from Desired Dataframe to a Dict with Frequency Counter & Sorted List

def genre_df_to_dict_counter(df_column):
    
    clean_series = df_column.replace('[]', np.nan).dropna()
    
    new = []
    for item in clean_series:
        for ch in ['\\','`','*','_','{','}','[',']','(',')'
                   ,'>','#','+','.','!','$','\'']:

            if ch in item:
                item = item.replace(ch,'')
        new.append(item)
    
    messy_string = ', '.join(new)
    
    clean_string = [item.strip() for item in messy_string.split(',')]
    dict_counter = {k:clean_string.count(k) for k in set(clean_string)}
    sorted_list = sorted(dict_counter.items(), key=lambda x: x[1], reverse=True)
    
    return dict_counter, sorted_list;

# %%
#Create a WordCloud from Dictionary Frequency

def dict_counter_to_WC(dc_counter, mask=None):
    
    # WordCloud Object
    wordcloud = WordCloud(max_words=5, 
                          contour_width=3, 
                          width=650, height=425,
                          background_color="white",
                          colormap='Set2',
                          prefer_horizontal=0.95,
                          mask=mask
                         )
    
    # Generate a word cloud
    wordcloud.generate_from_frequencies(dc_counter)

    # Visualize the word cloud
    # print (wordcloud.words_)
    # print(wordcloud.layout_)
    return wordcloud.to_image()

# %% [markdown]
# ## WordCloud for 60s

# %%
dc60s, sl60s = genre_df_to_dict_counter(bb60s_f['spotify_genre'])
#sl60s
dict_counter_to_WC(dc60s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA29363F790>

# %% [markdown]
# ## WordCloud for 70s

# %%
dc70s, sl70s = genre_df_to_dict_counter(bb70s_f['spotify_genre'])
#sl70s
dict_counter_to_WC(dc70s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA2B091A8E0>

# %%
#60s + 70s

dc67s, sl67s = genre_df_to_dict_counter(bb67['spotify_genre'])
#sl70s
dict_counter_to_WC(dc67s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA29363F7F0>

# %% [markdown]
# ## WordCloud for 80s

# %%
dc80s, sl80s = genre_df_to_dict_counter(bb80s_f['spotify_genre'])
#sl80s
dict_counter_to_WC(dc80s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA2956A1700>

# %% [markdown]
# ## WordCloud for 90s

# %%
dc90s, sl90s = genre_df_to_dict_counter(bb90s_f['spotify_genre'])
#sl90s
dict_counter_to_WC(dc90s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA2B091AA30>

# %%
#80s + 90s

dc89s, sl89s = genre_df_to_dict_counter(bb89['spotify_genre'])
#sl70s
dict_counter_to_WC(dc89s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA262A06A60>

# %% [markdown]
# ## WordCloud for 2000s

# %%
dc00s, sl00s = genre_df_to_dict_counter(bb2000s_f['spotify_genre'])
#sl00s
dict_counter_to_WC(dc00s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA262A06E80>

# %% [markdown]
# ## WordCloud for 2010s

# %%
dc10s, sl10s = genre_df_to_dict_counter(bb2010s_f['spotify_genre'])
#sl10s
dict_counter_to_WC(dc10s)
# Out:
# <PIL.Image.Image image mode=RGB size=650x425 at 0x7FA2956A1C40>
