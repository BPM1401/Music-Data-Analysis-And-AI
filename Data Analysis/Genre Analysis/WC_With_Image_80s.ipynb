# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker

from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from wordcloud import WordCloud

sns.set()
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.DatetimeIndex(bb100['WeekID'])
#bb100.sort_values(by='WeekID').iloc[np.r_[0:2, -2:0]]

# %%
#Merge BB100 with Features
bb100_f = pd.merge(bb100, features, on='SongID', how='left')

# %%
#Getting Data From The 60's, 70's, 80's, 90's, 00's, 10's
bb60s_f = bb100_f[(bb100_f['WeekID'] >= '1960-1-1') & (bb100_f['WeekID'] < '1970-1-1')]
bb70s_f = bb100_f[(bb100_f['WeekID'] >= '1970-1-1') & (bb100_f['WeekID'] < '1980-1-1')]
bb80s_f = bb100_f[(bb100_f['WeekID'] >= '1980-1-1') & (bb100_f['WeekID'] < '1990-1-1')]
bb90s_f = bb100_f[(bb100_f['WeekID'] >= '1990-1-1') & (bb100_f['WeekID'] < '2000-1-1')]
bb2000s_f = bb100_f[(bb100_f['WeekID'] >= '2000-1-1') & (bb100_f['WeekID'] < '2010-1-1')]
bb2010s_f = bb100_f[(bb100_f['WeekID'] >= '2010-1-1') & (bb100_f['WeekID'] < '2020-1-1')]

# %%
#Convert "Spotify Genres" from Desired Dataframe to a Dict with Frequency Counter & Sorted List

def genre_df_to_dict_counter(df_column):
    
    clean_series = df_column.replace('[]', np.nan).dropna()
    
    new = []
    for item in clean_series:
        for ch in ['\\','`','*','_','{','}','[',']','(',')'
                   ,'>','#','+','.','!','$','\'']:

            if ch in item:
                item = item.replace(ch,'')
        new.append(item)
    
    messy_string = ', '.join(new)
    
    clean_string = [item.strip() for item in messy_string.split(',')]
    dict_counter = {k:clean_string.count(k) for k in set(clean_string)}
    sorted_list = sorted(dict_counter.items(), key=lambda x: x[1], reverse=True)
    
    return dict_counter, sorted_list;

# %%
#Create a WordCloud from Dictionary Frequency


def dict_counter_to_WC(dc_counter, mask=None):
    
    from PIL import Image
    
    # WordCloud Object
    wordcloud = WordCloud(max_words=75, 
                          contour_width=3,
                          max_font_size = 70,
                          width=1000, height=1000,
                          background_color="white",
                          colormap='seismic',
                          prefer_horizontal=0.75,
                          mask=mask
                         )
    
    # Generate a word cloud
    wordcloud.generate_from_frequencies(dc_counter)
    
    #Save it locally
    wordcloud.to_file('80s_WC_with_Image.png')

    # Visualize the word cloud
    # print (wordcloud.words_)
    # print(wordcloud.layout_)
    return wordcloud.to_image()

# %%
#First Remove BG using Background Burner then...
#Convert image with no background to RGB format for WordCloud

from PIL import Image
  
def convertImage():
    img = Image.open("guitar.png")
    img = img.convert("RGBA")
  
    datas = img.getdata()
  
    newData = []
  
    for item in datas:
        if item[0] == 0 and item[1] == 0 and item[2] == 0:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
  
    img.putdata(newData)
    img.save("./New_Guitar.png", "PNG")
    print("Successful")
  
convertImage()
# Out:
# Successful

# %%
#Use new image as Mask
Guitar_mask = np.array(Image.open("New_Guitar.png"))

# %%
#Check the 255's
Guitar_mask[0:3]
# Out:
# array([[[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [ 10,   9,   7, 255],
#         [  5,   5,   3, 255],
#         [ 10,   9,   8, 255]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [  7,   6,   4, 255],
#         [  7,   6,   5, 255],
#         [  8,   7,   5, 255]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [  7,   6,   4, 255],
#         [  5,   4,   2, 255],
#         [ 14,  12,   9, 255]]], dtype=uint8)

# %%
dc80s, sl80s = genre_df_to_dict_counter(bb80s_f['spotify_genre'])
#sl80s
dict_counter_to_WC(dc80s,mask=Guitar_mask)
# Out:
# <PIL.Image.Image image mode=RGB size=388x643 at 0x7FCBCF06CC70>

# %%
sl80s
# Out:
# [('soft rock', 21973),
#  ('mellow gold', 19761),
#  ('rock', 15236),
#  ('album rock', 14993),
#  ('new wave pop', 13901),
#  ('classic rock', 10633),
#  ('dance rock', 9609),
#  ('new romantic', 7431),
#  ('quiet storm', 7115),
#  ('new wave', 6944),
#  ('disco', 6741),
#  ('folk rock', 6200),
#  ('hard rock', 5969),
#  ('adult standards', 5828),
#  ('funk', 5304),
#  ('motown', 5171),
#  ('art rock', 4616),
#  ('soul', 4499),
#  ('yacht rock', 4150),
#  ('heartland rock', 4057),
#  ('urban contemporary', 3692),
#  ('synthpop', 3608),
#  ('europop', 3350),
#  ('post-disco', 3323),
#  ('pop rock', 3283),
#  ('dance pop', 3190),
#  ('country rock', 3071),
#  ('new jack swing', 3068),
#  ('permanent wave', 2765),
#  ('singer-songwriter', 2554),
#  ('folk', 2553),
#  ('glam metal', 2504),
#  ('r&b', 1976),
#  ('roots rock', 1901),
#  ('bubblegum pop', 1851),
#  ('freestyle', 1685),
#  ('symphonic rock', 1642),
#  ('classic uk pop', 1555),
#  ('pop', 1417),
#  ('metal', 1362),
#  ('minneapolis sound', 1353),
#  ('classic soul', 1268),
#  ('blues rock', 1143),
#  ('glam rock', 1139),
#  ('progressive rock', 1126),
#  ('hi-nrg', 1092),
#  ('country', 1085),
#  ('brill building pop', 1074),
#  ('power pop', 1048),
#  ('classic country pop', 1036),
#  ('piano rock', 1004),
#  ('australian rock', 992),
#  ('psychedelic rock', 904),
#  ('neo soul', 903),
#  ('classic canadian rock', 900),
#  ('lounge', 700),
#  ('jazz funk', 644),
#  ('southern soul', 620),
#  ('smooth jazz', 593),
#  ('girl group', 525),
#  ('electro', 511),
#  ('rap', 504),
#  ('vocal jazz', 503),
#  ('protopunk', 495),
#  ('jangle pop', 485),
#  ('lilith', 473),
#  ('rock-and-roll', 465),
#  ('hip hop', 455),
#  ('funk rock', 454),
#  ('british invasion', 433),
#  ('nashville sound', 419),
#  ('pub rock', 418),
#  ('southern rock', 382),
#  ('latin pop', 381),
#  ('old school hip hop', 372),
#  ('post-punk', 354),
#  ('boy band', 353),
#  ('hollywood', 353),
#  ('zolo', 339),
#  ('indie pop', 308),
#  ('hip house', 302),
#  ('hip pop', 298),
#  ('australian pop', 298),
#  ('canadian pop', 296),
#  ('philly soul', 295),
#  ('alternative rock', 292),
#  ('latin', 290),
#  ('art pop', 283),
#  ('neo mellow', 262),
#  ('stomp and holler', 262),
#  ('east coast hip hop', 255),
#  ('country dawn', 254),
#  ('jazz fusion', 241),
#  ('tropical', 237),
#  ('candy pop', 236),
#  ('canadian singer-songwriter', 232),
#  ('australian dance', 232),
#  ('bachata', 231),
#  ('new americana', 231),
#  ('reggaeton', 231),
#  ('rockabilly', 229),
#  ('british soul', 227),
#  ('memphis soul', 224),
#  ('traditional folk', 222),
#  ('british blues', 220),
#  ('seattle indie', 220),
#  ('folk-pop', 220),
#  ('indie folk', 220),
#  ('easy listening', 213),
#  ('electric blues', 212),
#  ('bow pop', 191),
#  ('sleaze rock', 190),
#  ('nwobhm', 172),
#  ('baroque pop', 171),
#  ('deep soft rock', 165),
#  ('italian disco', 162),
#  ('sunshine pop', 158),
#  ('jazz blues', 157),
#  ('canadian metal', 156),
#  ('punk', 150),
#  ('swedish pop', 149),
#  ('country road', 146),
#  ('scottish new wave', 139),
#  ('blues', 137),
#  ('outlaw country', 135),
#  ('texas country', 133),
#  ('pop punk', 129),
#  ('irish rock', 129),
#  ('jazz guitar', 127),
#  ('uk reggae', 125),
#  ('modern blues', 124),
#  ('miami bass', 123),
#  ('queens hip hop', 122),
#  ('hardcore hip hop', 121),
#  ('philly indie', 119),
#  ('soul jazz', 119),
#  ('merseybeat', 117),
#  ('a cappella', 112),
#  ('edm', 110),
#  ('comic', 106),
#  ('pop rap', 105),
#  ('post-teen pop', 99),
#  ('canadian country', 99),
#  ('social media pop', 93),
#  ('popping', 91),
#  ('neon pop punk', 90),
#  ('german pop', 86),
#  ('neo classical metal', 83),
#  ('alternative metal', 81),
#  ('melancholia', 81),
#  ('electropop', 81),
#  ('post-grunge', 80),
#  ('brit funk', 79),
#  ('emo', 77),
#  ('swedish hard rock', 73),
#  ('instrumental surf', 73),
#  ('show tunes', 72),
#  ('rock steady', 72),
#  ('reggae fusion', 72),
#  ('broadway', 72),
#  ('j-poprock', 72),
#  ('idol rock', 72),
#  ('uk americana', 72),
#  ('southern hip hop', 70),
#  ('turbo folk', 69),
#  ('sevdah', 69),
#  ('yugoslav rock', 69),
#  ('alternative country', 67),
#  ('electro house', 67),
#  ('electropowerpop', 67),
#  ('big room', 67),
#  ('trancecore', 67),
#  ('escape room', 66),
#  ('gangster rap', 66),
#  ('eurodance', 66),
#  ('novelty', 66),
#  ('uk post-punk', 65),
#  ('disco house', 64),
#  ('smooth saxophone', 62),
#  ('electronica', 62),
#  ('brazilian jazz', 62),
#  ('movie tunes', 61),
#  ('christian rock', 60),
#  ('indie rock', 59),
#  ('dream pop', 59),
#  ('alternative dance', 59),
#  ('german rock', 58),
#  ('harlem hip hop', 57),
#  ('boston rock', 57),
#  ('samba', 57),
#  ('texas blues', 57),
#  ('bossa nova', 57),
#  ('canadian indie', 57),
#  ('australian alternative rock', 56),
#  ('experimental rock', 55),
#  ('industrial rock', 55),
#  ('modern rock', 54),
#  ('alternative r&b', 53),
#  ('christmas instrumental', 52),
#  ('garage rock', 52),
#  ('northern soul', 51),
#  ('theme', 48),
#  ('ska', 48),
#  ('nu metal', 48),
#  ('gothic rock', 47),
#  ('teen pop', 46),
#  ('underground power pop', 46),
#  ('modern uplift', 45),
#  ('melodic hardcore', 45),
#  ('rhythm and blues', 44),
#  ('synth punk', 43),
#  ('native american', 43),
#  ('comedy', 43),
#  ('deep new wave', 42),
#  ('diva house', 41),
#  ('new age', 41),
#  ('german hard rock', 41),
#  ('welsh rock', 40),
#  ('jam band', 40),
#  ('canadian folk', 40),
#  ('parody', 39),
#  ('new rave', 39),
#  ('reggae', 39),
#  ('roots reggae', 39),
#  ('comedy rock', 39),
#  ('alternative emo', 39),
#  ('asmr', 39),
#  ('anthem emo', 39),
#  ('antiviral pop', 39),
#  ('pop edm', 38),
#  ('country rap', 38),
#  ('madchester', 37),
#  ('christian metal', 37),
#  ('trip hop', 37),
#  ('grupera', 37),
#  ('ska revival', 36),
#  ('rap rock', 36),
#  ('bahamian pop', 35),
#  ('alberta country', 35),
#  ('chicago house', 35),
#  ('german metal', 35),
#  ('dutch rock', 35),
#  ('nederpop', 35),
#  ('dutch prog', 35),
#  ('banda', 34),
#  ('chamber pop', 34),
#  ('celtic', 34),
#  ('celtic rock', 34),
#  ('steampunk', 34),
#  ('funk metal', 33),
#  ('anti-folk', 33),
#  ('wrestling', 33),
#  ('swedish synthpop', 33),
#  ('indietronica', 31),
#  ('austropop', 31),
#  ('neo-singer-songwriter', 31),
#  ('deep disco', 31),
#  ('neue deutsche welle', 31),
#  ('new jersey rap', 31),
#  ('doo-wop', 30),
#  ('redneck', 30),
#  ('viral pop', 30),
#  ('turntablism', 30),
#  ('indie singer-songwriter', 29),
#  ('dublin indie', 29),
#  ('cyberpunk', 28),
#  ('orchestra', 28),
#  ('dreamo', 28),
#  ('cowpunk', 28),
#  ('progressive post-hardcore', 28),
#  ('cowboy western', 27),
#  ('new mexico music', 27),
#  ('christian alternative rock', 27),
#  ('jazz trumpet', 27),
#  ('christian music', 27),
#  ('nyc pop', 26),
#  ('harmonica blues', 25),
#  ('classic garage rock', 23),
#  ('indie soul', 23),
#  ('scottish rock', 23),
#  ('french hip hop', 23),
#  ('dance-punk', 23),
#  ('regional mexican', 23),
#  ('vapor soul', 23),
#  ('ska punk', 23),
#  ('norteno', 23),
#  ('speed metal', 22),
#  ('classic danish pop', 22),
#  ('french movie tunes', 22),
#  ('no wave', 22),
#  ('post-disco soul', 22),
#  ('lovers rock', 22),
#  ('instrumental rock', 22),
#  ('experimental', 22),
#  ('canadian blues', 22),
#  ('"australian childrens music"', 21),
#  ('deep contemporary country', 21),
#  ('cosmic american', 21),
#  ('acoustic pop', 20),
#  ('old school thrash', 20),
#  ('contemporary vocal jazz', 20),
#  ('disney', 20),
#  ('proto-techno', 20),
#  ('german soundtrack', 19),
#  ('slow core', 19),
#  ('electroclash', 19),
#  ('west coast rap', 19),
#  ('filmi', 18),
#  ('sufi', 18),
#  ('bronx hip hop', 18),
#  ('indian folk', 18),
#  ('arkansas country', 18),
#  ('modern bollywood', 18),
#  ('jazz piano', 18),
#  ('irish folk', 17),
#  ('noise pop', 17),
#  ('indie electropop', 17),
#  ('lo-fi', 17),
#  ('middle earth', 17),
#  ('indie poptimism', 17),
#  ('sacramento indie', 17),
#  ('mod revival', 17),
#  ('puerto rican pop', 17),
#  ('alternative hip hop', 17),
#  ('irish pub song', 17),
#  ('canadian celtic', 17),
#  ('skate punk', 17),
#  ('jazz rap', 17),
#  ('downtempo', 17),
#  ('birmingham metal', 16),
#  ('big beat', 16),
#  ('background music', 16),
#  ('soul blues', 15),
#  ('classic swedish pop', 15),
#  ('thrash metal', 15),
#  ('miami hip hop', 15),
#  ('bubblegum dance', 15),
#  ('bedroom pop', 15),
#  ('dirty texas rap', 14),
#  ('future funk', 14),
#  ('melodic hard rock', 14),
#  ('retro electro', 14),
#  ('south african jazz', 14),
#  ('deep pop r&b', 13),
#  ('nu jazz', 13),
#  ('dark techno', 13),
#  ('industrial techno', 13),
#  ('contemporary gospel', 13),
#  ('norwegian pop', 13),
#  ('swiss rock', 13),
#  ('classic norwegian pop', 13),
#  ('new age piano', 13),
#  ('minimal dub', 13),
#  ('acid jazz', 13),
#  ('french techno', 13),
#  ('san diego rap', 12),
#  ('classic opm', 12),
#  ('g funk', 12),
#  ('opm', 12),
#  ('contemporary folk', 12),
#  ('go-go', 12),
#  ('west coast trap', 12),
#  ('new beat', 12),
#  ('futurepop', 12),
#  ('new orleans jazz', 11),
#  ('dixieland', 11),
#  ('duranguense', 11),
#  ('detroit house', 11),
#  ('kiwi rock', 11),
#  ('swing', 11),
#  ('garage pop', 11),
#  ('orchestral performance', 11),
#  ('deep house', 11),
#  ('classical performance', 11),
#  ('acid house', 11),
#  ('vocal house', 11),
#  ('hardcore techno', 11),
#  ('didgeridoo', 11),
#  ('experimental pop', 10),
#  ('contemporary country', 10),
#  ('modern ska punk', 10),
#  ('modern southern rock', 10),
#  ('alternative pop', 10),
#  ('classic belgian pop', 10),
#  ('progressive jazz fusion', 10),
#  ('grime', 10),
#  ('audiophile vocal', 10),
#  ('belgian rock', 10),
#  ('modern alternative rock', 10),
#  ('contemporary post-bop', 9),
#  ('japanese city pop', 9),
#  ('deep eurodance', 9),
#  ('classic j-rock', 9),
#  ('instrumental funk', 9),
#  ('jazz saxophone', 9),
#  ('shibuya-kei', 9),
#  ('cool jazz', 9),
#  ('bebop', 9),
#  ('tropical house', 9),
#  ('jazz', 9),
#  ('classic soundtrack', 9),
#  ('hammond organ', 9),
#  ('vapor twitch', 9),
#  ('shimmer pop', 8),
#  ('scorecore', 8),
#  ('neo-progressive', 8),
#  ('indie punk', 8),
#  ('vogue', 8),
#  ('detroit hip hop', 8),
#  ('british choir', 8),
#  ('new jersey indie', 8),
#  ('folk punk', 8),
#  ('lgbtq hip hop', 8),
#  ('indie r&b', 8),
#  ('brooklyn indie', 8),
#  ('jazz organ', 8),
#  ('canterbury scene', 8),
#  ('swedish rockabilly', 8),
#  ('dub', 8),
#  ('uk pop', 7),
#  ('e6fi', 7),
#  ('oslo indie', 7),
#  ('christian relaxative', 7),
#  ('meme rap', 7),
#  ('operatic pop', 7),
#  ('classic praise', 7),
#  ('world worship', 7),
#  ('british folk', 7),
#  ('athens indie', 7),
#  ('conscious hip hop', 7),
#  ('groove metal', 7),
#  ('power metal', 7),
#  ('classical tenor', 7),
#  ('worship', 7),
#  ('freak folk', 7),
#  ('"childrens music"', 7),
#  ('p funk', 7),
#  ('drum and bass', 7),
#  ('dirty south rap', 7),
#  ('opera', 7),
#  ('deep latin christian', 6),
#  ('chicago indie', 6),
#  ('ccm', 6),
#  ('vapor trap', 6),
#  ('chicago rap', 6),
#  ('jazz violin', 6),
#  ('cedm', 6),
#  ('chanson', 6),
#  ('chicago soul', 6),
#  ('irish singer-songwriter', 6),
#  ('french pop', 6),
#  ('trap', 6),
#  ('christian pop', 6),
#  ('lo-fi beats', 6),
#  ('uk garage', 5),
#  ('swamp blues', 5),
#  ('dutch hip hop', 5),
#  ('swamp pop', 5),
#  ('southern soul blues', 5),
#  ('christian punk', 5),
#  ('birmingham hip hop', 5),
#  ('bossa nova jazz', 5),
#  ('deep punk rock', 5),
#  ('louisiana blues', 5),
#  ('basshall', 5),
#  ('dutch house', 5),
#  ('uk alternative hip hop', 5),
#  ('dutch urban', 5),
#  ('uk hip hop', 5),
#  ('unblack metal', 5),
#  ('swedish electropop', 4),
#  ('pixie', 4),
#  ('utah indie', 4),
#  ('american post-rock', 4),
#  ('post-rock', 4),
#  ('c86', 4),
#  ('wu fam', 4),
#  ('canadian electronic', 4),
#  ('dansktop', 4),
#  ('fake', 4),
#  ('gothenburg indie', 4),
#  ('chillwave', 4),
#  ('focus', 4),
#  ('compositional ambient', 4),
#  ('nerdcore', 3),
#  ('emo rap', 3),
#  ('ranchera', 3),
#  ('canadian hip hop', 3),
#  ('dark trap', 3),
#  ('ottawa rap', 3),
#  ('mallet', 3),
#  ('j-ambient', 3),
#  ('underground hip hop', 3),
#  ('otacore', 2),
#  ('anime', 2),
#  ('classic italian pop', 2),
#  ('la indie', 1)]
