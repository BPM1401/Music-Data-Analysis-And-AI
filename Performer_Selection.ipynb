# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.ticker as ticker
from IPython.display import Audio
from sklearn import datasets, linear_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 200)

# %%
#Billboard Top 100 By Week from 1958 to 2021
bb100 = pd.read_csv('Hot Stuff.csv')

# %%
#First & Last 2 entries by Week/Year
bb100['WeekID'] = pd.to_datetime(bb100['WeekID'])

# %%
#Features
features = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
bb_all = pd.merge(bb100, features, on='SongID', how='left')
bb_all
# Out:
#                                                         url     WeekID  \
# 0        http://www.billboard.com/charts/hot-100/1965-07-17 1965-07-17
# 1        http://www.billboard.com/charts/hot-100/1965-07-24 1965-07-24
# 2        http://www.billboard.com/charts/hot-100/1965-07-31 1965-07-31
# 3        http://www.billboard.com/charts/hot-100/1965-08-07 1965-08-07
# 4        http://www.billboard.com/charts/hot-100/1965-08-14 1965-08-14
# ...                                                     ...        ...
# 330456  https://www.billboard.com/charts/hot-100/2018-10-20 2018-10-20
# 330457   http://www.billboard.com/charts/hot-100/1977-05-21 1977-05-21
# 330458   http://www.billboard.com/charts/hot-100/1981-05-23 1981-05-23
# 330459   http://www.billboard.com/charts/hot-100/1973-09-29 1973-09-29
# 330460  https://www.billboard.com/charts/hot-100/2020-11-28 2020-11-28
#
#         Week Position                    Song_x                Performer_x  \
# 0                  34    Don't Just Stand There                 Patty Duke
# 1                  22    Don't Just Stand There                 Patty Duke
# 2                  14    Don't Just Stand There                 Patty Duke
# 3                  10    Don't Just Stand There                 Patty Duke
# 4                   8    Don't Just Stand There                 Patty Duke
# ...               ...                       ...                        ...
# 330456             22            God Is A Woman              Ariana Grande
# 330457             22   I Wanna Get Next To You                 Rose Royce
# 330458             22          I Can't Stand It  Eric Clapton And His Band
# 330459             22  Here I Am Come & Take Me                   Al Green
# 330460             22                     Hawai        Maluma & The Weeknd
#
#                                            SongID  Instance  \
# 0                Don't Just Stand TherePatty Duke         1
# 1                Don't Just Stand TherePatty Duke         1
# 2                Don't Just Stand TherePatty Duke         1
# 3                Don't Just Stand TherePatty Duke         1
# 4                Don't Just Stand TherePatty Duke         1
# ...                                           ...       ...
# 330456                God Is A WomanAriana Grande         1
# 330457          I Wanna Get Next To YouRose Royce         1
# 330458  I Can't Stand ItEric Clapton And His Band         1
# 330459           Here I Am Come & Take MeAl Green         1
# 330460                   HawaiMaluma & The Weeknd         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  \
# 0                         45.0             34               4
# 1                         34.0             22               5
# 2                         22.0             14               6
# 3                         14.0             10               7
# 4                         10.0              8               8
# ...                        ...            ...             ...
# 330456                    21.0              8              13
# 330457                    10.0             10              13
# 330458                    12.0             10              13
# 330459                    16.0             10              13
# 330460                    12.0             12              13
#
#                       Performer_y                    Song_y  \
# 0                      Patty Duke    Don't Just Stand There
# 1                      Patty Duke    Don't Just Stand There
# 2                      Patty Duke    Don't Just Stand There
# 3                      Patty Duke    Don't Just Stand There
# 4                      Patty Duke    Don't Just Stand There
# ...                           ...                       ...
# 330456              Ariana Grande            God Is A Woman
# 330457                 Rose Royce   I Wanna Get Next To You
# 330458  Eric Clapton And His Band          I Can't Stand It
# 330459                   Al Green  Here I Am Come & Take Me
# 330460        Maluma & The Weeknd                     Hawai
#
#                                                                                          spotify_genre  \
# 0                                                                             ['deep adult standards']
# 1                                                                             ['deep adult standards']
# 2                                                                             ['deep adult standards']
# 3                                                                             ['deep adult standards']
# 4                                                                             ['deep adult standards']
# ...                                                                                                ...
# 330456                                                           ['dance pop', 'pop', 'post-teen pop']
# 330457                ['classic soul', 'disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# 330458                                                                                             NaN
# 330459  ['classic soul', 'funk', 'memphis soul', 'quiet storm', 'soul', 'soul blues', 'southern soul']
# 330460                                                                                             NaN
#
#               spotify_track_id  \
# 0       1YhNCQ3XOdTCZgubfX8PgB
# 1       1YhNCQ3XOdTCZgubfX8PgB
# 2       1YhNCQ3XOdTCZgubfX8PgB
# 3       1YhNCQ3XOdTCZgubfX8PgB
# 4       1YhNCQ3XOdTCZgubfX8PgB
# ...                        ...
# 330456  67kQ3UW7saqCFqB54BVKKI
# 330457  1rff5WJrSljfCLYFoXkDiT
# 330458                     NaN
# 330459  20wu6USlvWRghMOvUdfLgE
# 330460                     NaN
#
#                                                                                           spotify_track_preview_url  \
# 0                                                                                                               NaN
# 1                                                                                                               NaN
# 2                                                                                                               NaN
# 3                                                                                                               NaN
# 4                                                                                                               NaN
# ...                                                                                                             ...
# 330456                                                                                                          NaN
# 330457                                                                                                          NaN
# 330458                                                                                                          NaN
# 330459  https://p.scdn.co/mp3-preview/37dbfd6ef26ecbbdaf4c9564ef8a5230767308ae?cid=b8d3901151d34489a160e3cf0ab1fa94
# 330460                                                                                                          NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 0                        163160.0                     0.0
# 1                        163160.0                     0.0
# 2                        163160.0                     0.0
# 3                        163160.0                     0.0
# 4                        163160.0                     0.0
# ...                           ...                     ...
# 330456                   213068.0                     0.0
# 330457                   238200.0                     0.0
# 330458                        NaN                     NaN
# 330459                   256693.0                     0.0
# 330460                        NaN                     NaN
#
#                                             spotify_track_album  danceability  \
# 0       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 1       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 2       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 3       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# 4       Lost Hits Of The 60's (All Original Artists & Versions)         0.574
# ...                                                         ...           ...
# 330456                                 k bye for now (swt live)         0.602
# 330457                                                 Car Wash         0.620
# 330458                                                      NaN           NaN
# 330459                                                  Call Me         0.815
# 330460                                                      NaN           NaN
#
#         energy   key  loudness  mode  speechiness  acousticness  \
# 0        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 1        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 2        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 3        0.256   7.0   -15.044   1.0       0.0298        0.6100
# 4        0.256   7.0   -15.044   1.0       0.0298        0.6100
# ...        ...   ...       ...   ...          ...           ...
# 330456   0.658   1.0    -5.934   1.0       0.0558        0.0233
# 330457   0.179   0.0   -19.981   1.0       0.0314        0.8350
# 330458     NaN   NaN       NaN   NaN          NaN           NaN
# 330459   0.388  11.0   -12.238   0.0       0.0364        0.3180
# 330460     NaN   NaN       NaN   NaN          NaN           NaN
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000077    0.1000    0.568   82.331             3.0
# 1               0.000077    0.1000    0.568   82.331             3.0
# 2               0.000077    0.1000    0.568   82.331             3.0
# 3               0.000077    0.1000    0.568   82.331             3.0
# 4               0.000077    0.1000    0.568   82.331             3.0
# ...                  ...       ...      ...      ...             ...
# 330456          0.000060    0.2370    0.268  145.031             4.0
# 330457          0.030000    0.0928    0.675  130.864             4.0
# 330458               NaN       NaN      NaN      NaN             NaN
# 330459          0.000084    0.0673    0.846   94.558             4.0
# 330460               NaN       NaN      NaN      NaN             NaN
#
#         spotify_track_popularity
# 0                           21.0
# 1                           21.0
# 2                           21.0
# 3                           21.0
# 4                           21.0
# ...                          ...
# 330456                      62.0
# 330457                      51.0
# 330458                       NaN
# 330459                      52.0
# 330460                       NaN
#
# [330461 rows x 31 columns]

# %%
perf_dance = bb_all.groupby('Performer_x').mean()['danceability'].to_frame()
perf_dance
# Out:
#                                                                            danceability
# Performer_x
# "Groove" Holmes                                                                0.553000
# "Little" Jimmy Dickens                                                         0.660000
# "Pookie" Hudson                                                                     NaN
# "Weird Al" Yankovic                                                            0.731308
# 'N Sync                                                                             NaN
# ...                                                                                 ...
# will.i.am & Nicki Minaj                                                        0.854000
# will.i.am Featuring Justin Bieber                                              0.797000
# will.i.am Featuring Mick Jagger & Jennifer Lopez                               0.586000
# will.i.am Featuring Miley Cyrus                                                0.619000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard      0.859000
#
# [10061 rows x 1 columns]

# %%
selected_dance = perf_dance[(perf_dance.danceability>0.577)&
                            (perf_dance.danceability<0.726)]
selected_dance
# Out:
#                                                   danceability
# Performer_x
# "Little" Jimmy Dickens                                0.660000
# 10,000 Maniacs                                        0.664130
# 10cc                                                  0.583280
# 112                                                   0.720282
# 112 Featuring Foxy Brown                              0.677000
# ...                                                        ...
# k.d. lang                                             0.582800
# lovelytheband                                         0.666000
# twenty one pilots                                     0.704686
# will.i.am Featuring Mick Jagger & Jennifer Lopez      0.586000
# will.i.am Featuring Miley Cyrus                       0.619000
#
# [2930 rows x 1 columns]

# %%
perf_val = bb_all.groupby('Performer_x').mean()['valence'].to_frame()
perf_val
# Out:
#                                                                             valence
# Performer_x
# "Groove" Holmes                                                            0.524000
# "Little" Jimmy Dickens                                                     0.867000
# "Pookie" Hudson                                                                 NaN
# "Weird Al" Yankovic                                                        0.776681
# 'N Sync                                                                         NaN
# ...                                                                             ...
# will.i.am & Nicki Minaj                                                    0.686000
# will.i.am Featuring Justin Bieber                                          0.403000
# will.i.am Featuring Mick Jagger & Jennifer Lopez                           0.450000
# will.i.am Featuring Miley Cyrus                                            0.338000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.514000
#
# [10061 rows x 1 columns]

# %%
selected_val = perf_val[(perf_val.valence>0.394)&
                        (perf_val.valence<0.604)]
selected_val
# Out:
#                                                                             valence
# Performer_x
# "Groove" Holmes                                                            0.524000
# 'Til Tuesday                                                               0.581264
# 0                                                                          0.580000
# 10cc                                                                       0.522744
# 1927                                                                       0.395000
# ...                                                                             ...
# twenty one pilots                                                          0.583447
# will.i.am & Britney Spears                                                 0.501000
# will.i.am Featuring Justin Bieber                                          0.403000
# will.i.am Featuring Mick Jagger & Jennifer Lopez                           0.450000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.514000
#
# [2277 rows x 1 columns]

# %%
df_inner = pd.merge(selected_dance, selected_val, on='Performer_x', how='inner')
df_inner
# Out:
#                                                   danceability   valence
# Performer_x
# 10cc                                                  0.583280  0.522744
# 2 Chainz Featuring Ariana Grande                      0.592000  0.447000
# 311                                                   0.625000  0.556000
# 50 Cent Featuring Eminem & Adam Levine                0.646000  0.518000
# 6ix9ine                                               0.708458  0.525250
# ...                                                        ...       ...
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
# lovelytheband                                         0.666000  0.510000
# twenty one pilots                                     0.704686  0.583447
# will.i.am Featuring Mick Jagger & Jennifer Lopez      0.586000  0.450000
#
# [809 rows x 2 columns]

# %%
perf_speechy = bb_all.groupby('Performer_x').mean()['speechiness'].to_frame()
perf_speechy
# Out:
#                                                                            speechiness
# Performer_x
# "Groove" Holmes                                                               0.032400
# "Little" Jimmy Dickens                                                        0.115000
# "Pookie" Hudson                                                                    NaN
# "Weird Al" Yankovic                                                           0.087407
# 'N Sync                                                                            NaN
# ...                                                                                ...
# will.i.am & Nicki Minaj                                                       0.059800
# will.i.am Featuring Justin Bieber                                             0.058300
# will.i.am Featuring Mick Jagger & Jennifer Lopez                              0.096900
# will.i.am Featuring Miley Cyrus                                               0.035700
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard     0.156000
#
# [10061 rows x 1 columns]

# %%
selected_speechy = perf_speechy[(perf_speechy.speechiness>0.053)&
                            (perf_speechy.speechiness<0.162)]
selected_speechy
# Out:
#                                                                            speechiness
# Performer_x
# "Little" Jimmy Dickens                                                        0.115000
# "Weird Al" Yankovic                                                           0.087407
# (+44)                                                                         0.123000
# 10 Years                                                                      0.081300
# 10cc                                                                          0.059845
# ...                                                                                ...
# will.i.am & Britney Spears                                                    0.069600
# will.i.am & Nicki Minaj                                                       0.059800
# will.i.am Featuring Justin Bieber                                             0.058300
# will.i.am Featuring Mick Jagger & Jennifer Lopez                              0.096900
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard     0.156000
#
# [2358 rows x 1 columns]

# %%
df_inner2 = pd.merge(df_inner, selected_speechy, on='Performer_x', how='inner')
df_inner2
# Out:
#                                                   danceability   valence  \
# Performer_x
# 10cc                                                  0.583280  0.522744
# 2 Chainz Featuring Ariana Grande                      0.592000  0.447000
# A Great Big World Featuring FUTURISTIC                0.610000  0.510000
# Aaron Neville                                         0.635313  0.571438
# Ace Hood Featuring Chris Brown                        0.603000  0.561000
# ...                                                        ...       ...
# Zedd & Alessia Cara                                   0.690000  0.544000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
# twenty one pilots                                     0.704686  0.583447
# will.i.am Featuring Mick Jagger & Jennifer Lopez      0.586000  0.450000
#
#                                                   speechiness
# Performer_x
# 10cc                                                 0.059845
# 2 Chainz Featuring Ariana Grande                     0.089300
# A Great Big World Featuring FUTURISTIC               0.065600
# Aaron Neville                                        0.076431
# Ace Hood Featuring Chris Brown                       0.056600
# ...                                                       ...
# Zedd & Alessia Cara                                  0.062200
# benny blanco & Juice WRLD Featuring Brendon Urie     0.154000
# gnash Featuring Johnny Yukon                         0.090100
# twenty one pilots                                    0.072611
# will.i.am Featuring Mick Jagger & Jennifer Lopez     0.096900
#
# [257 rows x 3 columns]

# %%
len(df_inner2)
# Out:
# 257

# %%
perf_inst = bb_all.groupby('Performer_x').mean()['instrumentalness'].to_frame()
perf_inst
# Out:
#                                                                            instrumentalness
# Performer_x
# "Groove" Holmes                                                                    0.876000
# "Little" Jimmy Dickens                                                             0.000010
# "Pookie" Hudson                                                                         NaN
# "Weird Al" Yankovic                                                                0.000216
# 'N Sync                                                                                 NaN
# ...                                                                                     ...
# will.i.am & Nicki Minaj                                                            0.000008
# will.i.am Featuring Justin Bieber                                                  0.000077
# will.i.am Featuring Mick Jagger & Jennifer Lopez                                   0.000006
# will.i.am Featuring Miley Cyrus                                                    0.003320
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard          0.000000
#
# [10061 rows x 1 columns]

# %%
selected_inst = perf_inst[(perf_inst.instrumentalness>-0.006)&
                          (perf_inst.instrumentalness<0.012)]
selected_inst
# Out:
#                                                                            instrumentalness
# Performer_x
# "Little" Jimmy Dickens                                                             0.000010
# "Weird Al" Yankovic                                                                0.000216
# (+44)                                                                              0.000000
# 0                                                                                  0.000532
# 10 Years                                                                           0.000208
# ...                                                                                     ...
# will.i.am & Nicki Minaj                                                            0.000008
# will.i.am Featuring Justin Bieber                                                  0.000077
# will.i.am Featuring Mick Jagger & Jennifer Lopez                                   0.000006
# will.i.am Featuring Miley Cyrus                                                    0.003320
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard          0.000000
#
# [6437 rows x 1 columns]

# %%
df_inner3 = pd.merge(df_inner2, selected_inst, on='Performer_x', how='inner')
df_inner3
# Out:
#                                                   danceability   valence  \
# Performer_x
# 10cc                                                  0.583280  0.522744
# 2 Chainz Featuring Ariana Grande                      0.592000  0.447000
# A Great Big World Featuring FUTURISTIC                0.610000  0.510000
# Aaron Neville                                         0.635313  0.571438
# Ace Hood Featuring Chris Brown                        0.603000  0.561000
# ...                                                        ...       ...
# Zedd & Alessia Cara                                   0.690000  0.544000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
# twenty one pilots                                     0.704686  0.583447
# will.i.am Featuring Mick Jagger & Jennifer Lopez      0.586000  0.450000
#
#                                                   speechiness  \
# Performer_x
# 10cc                                                 0.059845
# 2 Chainz Featuring Ariana Grande                     0.089300
# A Great Big World Featuring FUTURISTIC               0.065600
# Aaron Neville                                        0.076431
# Ace Hood Featuring Chris Brown                       0.056600
# ...                                                       ...
# Zedd & Alessia Cara                                  0.062200
# benny blanco & Juice WRLD Featuring Brendon Urie     0.154000
# gnash Featuring Johnny Yukon                         0.090100
# twenty one pilots                                    0.072611
# will.i.am Featuring Mick Jagger & Jennifer Lopez     0.096900
#
#                                                   instrumentalness
# Performer_x
# 10cc                                                      0.004388
# 2 Chainz Featuring Ariana Grande                          0.000003
# A Great Big World Featuring FUTURISTIC                    0.000000
# Aaron Neville                                             0.001501
# Ace Hood Featuring Chris Brown                            0.000000
# ...                                                            ...
# Zedd & Alessia Cara                                       0.000000
# benny blanco & Juice WRLD Featuring Brendon Urie          0.000000
# gnash Featuring Johnny Yukon                              0.000000
# twenty one pilots                                         0.004706
# will.i.am Featuring Mick Jagger & Jennifer Lopez          0.000006
#
# [232 rows x 4 columns]

# %%
len(df_inner3)
# Out:
# 232

# %%
perf_energy = bb_all.groupby('Performer_x').mean()['energy'].to_frame()
perf_energy
# Out:
#                                                                              energy
# Performer_x
# "Groove" Holmes                                                            0.487000
# "Little" Jimmy Dickens                                                     0.801000
# "Pookie" Hudson                                                                 NaN
# "Weird Al" Yankovic                                                        0.669165
# 'N Sync                                                                         NaN
# ...                                                                             ...
# will.i.am & Nicki Minaj                                                    0.667000
# will.i.am Featuring Justin Bieber                                          0.608000
# will.i.am Featuring Mick Jagger & Jennifer Lopez                           0.712000
# will.i.am Featuring Miley Cyrus                                            0.621000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.533000
#
# [10061 rows x 1 columns]

# %%
selected_energy = perf_energy[(perf_energy.energy>0.51)&
                              (perf_energy.energy<0.677)]
selected_energy
# Out:
#                                                                              energy
# Performer_x
# "Weird Al" Yankovic                                                        0.669165
# 'Til Tuesday                                                               0.557340
# 0                                                                          0.572000
# 10,000 Maniacs                                                             0.665609
# 10cc                                                                       0.522512
# ...                                                                             ...
# twenty one pilots                                                          0.591730
# will.i.am & Nicki Minaj                                                    0.667000
# will.i.am Featuring Justin Bieber                                          0.608000
# will.i.am Featuring Miley Cyrus                                            0.621000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.533000
#
# [2460 rows x 1 columns]

# %%
df_inner4 = pd.merge(df_inner3, selected_energy, on='Performer_x', how='inner')
df_inner4
# Out:
#                                                   danceability   valence  \
# Performer_x
# 10cc                                                  0.583280  0.522744
# 2 Chainz Featuring Ariana Grande                      0.592000  0.447000
# Alannah Myles                                         0.718865  0.482000
# Ali Thomson                                           0.616500  0.551786
# Arizona Zervas                                        0.621000  0.457000
# ...                                                        ...       ...
# Wyclef Jean                                           0.674000  0.452000
# Zedd & Alessia Cara                                   0.690000  0.544000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
# twenty one pilots                                     0.704686  0.583447
#
#                                                   speechiness  \
# Performer_x
# 10cc                                                 0.059845
# 2 Chainz Featuring Ariana Grande                     0.089300
# Alannah Myles                                        0.054284
# Ali Thomson                                          0.064000
# Arizona Zervas                                       0.148000
# ...                                                       ...
# Wyclef Jean                                          0.085500
# Zedd & Alessia Cara                                  0.062200
# benny blanco & Juice WRLD Featuring Brendon Urie     0.154000
# gnash Featuring Johnny Yukon                         0.090100
# twenty one pilots                                    0.072611
#
#                                                   instrumentalness    energy
# Performer_x
# 10cc                                                      0.004388  0.522512
# 2 Chainz Featuring Ariana Grande                          0.000003  0.584000
# Alannah Myles                                             0.000870  0.562054
# Ali Thomson                                               0.000006  0.632786
# Arizona Zervas                                            0.000000  0.601000
# ...                                                            ...       ...
# Wyclef Jean                                               0.000045  0.536000
# Zedd & Alessia Cara                                       0.000000  0.622000
# benny blanco & Juice WRLD Featuring Brendon Urie          0.000000  0.600000
# gnash Featuring Johnny Yukon                              0.000000  0.518000
# twenty one pilots                                         0.004706  0.591730
#
# [78 rows x 5 columns]

# %%
perf_acous = bb_all.groupby('Performer_x').mean()['acousticness'].to_frame()
perf_acous
# Out:
#                                                                            acousticness
# Performer_x
# "Groove" Holmes                                                                0.783000
# "Little" Jimmy Dickens                                                         0.738000
# "Pookie" Hudson                                                                     NaN
# "Weird Al" Yankovic                                                            0.132022
# 'N Sync                                                                             NaN
# ...                                                                                 ...
# will.i.am & Nicki Minaj                                                        0.070500
# will.i.am Featuring Justin Bieber                                              0.001120
# will.i.am Featuring Mick Jagger & Jennifer Lopez                               0.104000
# will.i.am Featuring Miley Cyrus                                                0.009940
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard      0.029300
#
# [10061 rows x 1 columns]

# %%
selected_acous = perf_acous[(perf_acous.acousticness>0.158)&
                            (perf_acous.acousticness<0.42)]
selected_acous
# Out:
#                                                   acousticness
# Performer_x
# 10,000 Maniacs                                        0.414965
# 10cc                                                  0.340788
# 112 Featuring Foxy Brown                              0.224000
# 1910 Fruitgum Co.                                     0.344016
# 2 Chainz                                              0.329290
# ...                                                        ...
# a-ha                                                  0.278537
# benny blanco & Juice WRLD Featuring Brendon Urie      0.166000
# dc Talk                                               0.166000
# for KING & COUNTRY                                    0.395000
# gnash Featuring Johnny Yukon                          0.195000
#
# [2069 rows x 1 columns]

# %%
df_inner5 = pd.merge(df_inner4, selected_acous, on='Performer_x', how='inner')
df_inner5
# Out:
#                                                   danceability   valence  \
# Performer_x
# 10cc                                                  0.583280  0.522744
# Alannah Myles                                         0.718865  0.482000
# Brandy                                                0.642388  0.565153
# Dru Hill                                              0.677326  0.491087
# Fabolous Featuring Ne-Yo                              0.605000  0.573000
# Faith Evans                                           0.648719  0.535119
# Fantasia                                              0.655598  0.555536
# Ginuwine                                              0.690966  0.600904
# Gyptian                                               0.690000  0.497000
# Halsey                                                0.670697  0.478192
# Jaheim                                                0.663146  0.591683
# Jazmine Sullivan                                      0.646028  0.589542
# Jennifer Lopez Featuring LL Cool J                    0.699000  0.472000
# Jeremih                                               0.687239  0.555104
# Jodeci                                                0.654795  0.596144
# Justin Bieber                                         0.640524  0.518942
# Kanye West, R. Kelly                                  0.722000  0.534000
# Lil Nas X                                             0.713385  0.602077
# Lil Skies                                             0.683500  0.475000
# Lil Skies Featuring Landon Cube                       0.712273  0.457576
# Marques Houston                                       0.715741  0.434926
# Mike Posner Featuring Lil Wayne                       0.626000  0.523000
# Monica                                                0.633815  0.561908
# Musiq                                                 0.591594  0.449891
# Ne-Yo                                                 0.676383  0.530988
# Nick Jonas Featuring Tove Lo                          0.653000  0.401000
# Sisqo                                                 0.724593  0.524333
# Steve Holy                                            0.601362  0.447489
# Taylor Swift                                          0.605309  0.476707
# The Rubinoos                                          0.585000  0.505000
# Trey Songz                                            0.641241  0.436245
# Zedd & Alessia Cara                                   0.690000  0.544000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
#
#                                                   speechiness  \
# Performer_x
# 10cc                                                 0.059845
# Alannah Myles                                        0.054284
# Brandy                                               0.085446
# Dru Hill                                             0.085821
# Fabolous Featuring Ne-Yo                             0.096700
# Faith Evans                                          0.085249
# Fantasia                                             0.089899
# Ginuwine                                             0.081295
# Gyptian                                              0.060000
# Halsey                                               0.057210
# Jaheim                                               0.104782
# Jazmine Sullivan                                     0.064340
# Jennifer Lopez Featuring LL Cool J                   0.106000
# Jeremih                                              0.057404
# Jodeci                                               0.098475
# Justin Bieber                                        0.119881
# Kanye West, R. Kelly                                 0.124000
# Lil Nas X                                            0.107508
# Lil Skies                                            0.125500
# Lil Skies Featuring Landon Cube                      0.124788
# Marques Houston                                      0.146437
# Mike Posner Featuring Lil Wayne                      0.053400
# Monica                                               0.087149
# Musiq                                                0.131465
# Ne-Yo                                                0.098842
# Nick Jonas Featuring Tove Lo                         0.082000
# Sisqo                                                0.068381
# Steve Holy                                           0.057206
# Taylor Swift                                         0.055582
# The Rubinoos                                         0.071900
# Trey Songz                                           0.082700
# Zedd & Alessia Cara                                  0.062200
# benny blanco & Juice WRLD Featuring Brendon Urie     0.154000
# gnash Featuring Johnny Yukon                         0.090100
#
#                                                   instrumentalness    energy  \
# Performer_x
# 10cc                                                  4.388146e-03  0.522512
# Alannah Myles                                         8.702595e-04  0.562054
# Brandy                                                2.239602e-03  0.574796
# Dru Hill                                              0.000000e+00  0.547638
# Fabolous Featuring Ne-Yo                              0.000000e+00  0.614000
# Faith Evans                                           2.429630e-07  0.586793
# Fantasia                                              2.428557e-05  0.561278
# Ginuwine                                              5.812895e-03  0.532379
# Gyptian                                               2.810000e-05  0.621000
# Halsey                                                8.226239e-06  0.577432
# Jaheim                                                4.219512e-06  0.519354
# Jazmine Sullivan                                      0.000000e+00  0.621694
# Jennifer Lopez Featuring LL Cool J                    0.000000e+00  0.668000
# Jeremih                                               0.000000e+00  0.553448
# Jodeci                                                4.908718e-07  0.526518
# Justin Bieber                                         2.440528e-04  0.604489
# Kanye West, R. Kelly                                  0.000000e+00  0.556000
# Lil Nas X                                             0.000000e+00  0.561615
# Lil Skies                                             0.000000e+00  0.610000
# Lil Skies Featuring Landon Cube                       0.000000e+00  0.668424
# Marques Houston                                       3.505185e-06  0.550963
# Mike Posner Featuring Lil Wayne                       0.000000e+00  0.670000
# Monica                                                2.360761e-05  0.560826
# Musiq                                                 0.000000e+00  0.613941
# Ne-Yo                                                 4.241312e-05  0.651478
# Nick Jonas Featuring Tove Lo                          0.000000e+00  0.623000
# Sisqo                                                 1.021481e-04  0.673630
# Steve Holy                                            0.000000e+00  0.658383
# Taylor Swift                                          7.053505e-04  0.655652
# The Rubinoos                                          0.000000e+00  0.565000
# Trey Songz                                            4.229046e-06  0.634664
# Zedd & Alessia Cara                                   0.000000e+00  0.622000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.000000e+00  0.600000
# gnash Featuring Johnny Yukon                          0.000000e+00  0.518000
#
#                                                   acousticness
# Performer_x
# 10cc                                                  0.340788
# Alannah Myles                                         0.178167
# Brandy                                                0.296791
# Dru Hill                                              0.240246
# Fabolous Featuring Ne-Yo                              0.291000
# Faith Evans                                           0.213951
# Fantasia                                              0.360249
# Ginuwine                                              0.204820
# Gyptian                                               0.321000
# Halsey                                                0.182748
# Jaheim                                                0.205780
# Jazmine Sullivan                                      0.209658
# Jennifer Lopez Featuring LL Cool J                    0.265000
# Jeremih                                               0.288418
# Jodeci                                                0.261856
# Justin Bieber                                         0.320002
# Kanye West, R. Kelly                                  0.211000
# Lil Nas X                                             0.283846
# Lil Skies                                             0.382500
# Lil Skies Featuring Landon Cube                       0.393364
# Marques Houston                                       0.210378
# Mike Posner Featuring Lil Wayne                       0.318000
# Monica                                                0.200023
# Musiq                                                 0.324406
# Ne-Yo                                                 0.308717
# Nick Jonas Featuring Tove Lo                          0.253000
# Sisqo                                                 0.204222
# Steve Holy                                            0.274702
# Taylor Swift                                          0.186298
# The Rubinoos                                          0.266000
# Trey Songz                                            0.213328
# Zedd & Alessia Cara                                   0.253000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.166000
# gnash Featuring Johnny Yukon                          0.195000

# %%
len(df_inner5)
# Out:
# 34

# %%
perf_live = bb_all.groupby('Performer_x').mean()['liveness'].to_frame()
perf_live
# Out:
#                                                                            liveness
# Performer_x
# "Groove" Holmes                                                            0.292000
# "Little" Jimmy Dickens                                                     0.627000
# "Pookie" Hudson                                                                 NaN
# "Weird Al" Yankovic                                                        0.140924
# 'N Sync                                                                         NaN
# ...                                                                             ...
# will.i.am & Nicki Minaj                                                    0.119000
# will.i.am Featuring Justin Bieber                                          0.074800
# will.i.am Featuring Mick Jagger & Jennifer Lopez                           0.037700
# will.i.am Featuring Miley Cyrus                                            0.121000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.138000
#
# [10061 rows x 1 columns]

# %%
perf_live.loc['Ne-Yo']
# Out:
# liveness    0.33327
# Name: Ne-Yo, dtype: float64

# %%
selected_live = perf_live[(perf_live.liveness>0.102)&
                          (perf_live.liveness<0.219)]
selected_live
# Out:
#                                                                            liveness
# Performer_x
# "Weird Al" Yankovic                                                        0.140924
# 'Til Tuesday                                                               0.169006
# 0                                                                          0.105000
# 10,000 Maniacs                                                             0.108765
# 10cc                                                                       0.171202
# ...                                                                             ...
# t.A.T.u.                                                                   0.105000
# will.i.am & Britney Spears                                                 0.131000
# will.i.am & Nicki Minaj                                                    0.119000
# will.i.am Featuring Miley Cyrus                                            0.121000
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard  0.138000
#
# [3564 rows x 1 columns]

# %%
df_inner6 = pd.merge(df_inner5, selected_live, on='Performer_x', how='inner')
df_inner6
# Out:
#                                                   danceability   valence  \
# Performer_x
# 10cc                                                  0.583280  0.522744
# Alannah Myles                                         0.718865  0.482000
# Dru Hill                                              0.677326  0.491087
# Fabolous Featuring Ne-Yo                              0.605000  0.573000
# Faith Evans                                           0.648719  0.535119
# Fantasia                                              0.655598  0.555536
# Halsey                                                0.670697  0.478192
# Jaheim                                                0.663146  0.591683
# Jazmine Sullivan                                      0.646028  0.589542
# Jennifer Lopez Featuring LL Cool J                    0.699000  0.472000
# Jeremih                                               0.687239  0.555104
# Justin Bieber                                         0.640524  0.518942
# Kanye West, R. Kelly                                  0.722000  0.534000
# Lil Nas X                                             0.713385  0.602077
# Lil Skies                                             0.683500  0.475000
# Marques Houston                                       0.715741  0.434926
# Monica                                                0.633815  0.561908
# Musiq                                                 0.591594  0.449891
# Nick Jonas Featuring Tove Lo                          0.653000  0.401000
# Taylor Swift                                          0.605309  0.476707
# Zedd & Alessia Cara                                   0.690000  0.544000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.613000  0.532000
# gnash Featuring Johnny Yukon                          0.704000  0.527000
#
#                                                   speechiness  \
# Performer_x
# 10cc                                                 0.059845
# Alannah Myles                                        0.054284
# Dru Hill                                             0.085821
# Fabolous Featuring Ne-Yo                             0.096700
# Faith Evans                                          0.085249
# Fantasia                                             0.089899
# Halsey                                               0.057210
# Jaheim                                               0.104782
# Jazmine Sullivan                                     0.064340
# Jennifer Lopez Featuring LL Cool J                   0.106000
# Jeremih                                              0.057404
# Justin Bieber                                        0.119881
# Kanye West, R. Kelly                                 0.124000
# Lil Nas X                                            0.107508
# Lil Skies                                            0.125500
# Marques Houston                                      0.146437
# Monica                                               0.087149
# Musiq                                                0.131465
# Nick Jonas Featuring Tove Lo                         0.082000
# Taylor Swift                                         0.055582
# Zedd & Alessia Cara                                  0.062200
# benny blanco & Juice WRLD Featuring Brendon Urie     0.154000
# gnash Featuring Johnny Yukon                         0.090100
#
#                                                   instrumentalness    energy  \
# Performer_x
# 10cc                                                  4.388146e-03  0.522512
# Alannah Myles                                         8.702595e-04  0.562054
# Dru Hill                                              0.000000e+00  0.547638
# Fabolous Featuring Ne-Yo                              0.000000e+00  0.614000
# Faith Evans                                           2.429630e-07  0.586793
# Fantasia                                              2.428557e-05  0.561278
# Halsey                                                8.226239e-06  0.577432
# Jaheim                                                4.219512e-06  0.519354
# Jazmine Sullivan                                      0.000000e+00  0.621694
# Jennifer Lopez Featuring LL Cool J                    0.000000e+00  0.668000
# Jeremih                                               0.000000e+00  0.553448
# Justin Bieber                                         2.440528e-04  0.604489
# Kanye West, R. Kelly                                  0.000000e+00  0.556000
# Lil Nas X                                             0.000000e+00  0.561615
# Lil Skies                                             0.000000e+00  0.610000
# Marques Houston                                       3.505185e-06  0.550963
# Monica                                                2.360761e-05  0.560826
# Musiq                                                 0.000000e+00  0.613941
# Nick Jonas Featuring Tove Lo                          0.000000e+00  0.623000
# Taylor Swift                                          7.053505e-04  0.655652
# Zedd & Alessia Cara                                   0.000000e+00  0.622000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.000000e+00  0.600000
# gnash Featuring Johnny Yukon                          0.000000e+00  0.518000
#
#                                                   acousticness  liveness
# Performer_x
# 10cc                                                  0.340788  0.171202
# Alannah Myles                                         0.178167  0.179784
# Dru Hill                                              0.240246  0.164113
# Fabolous Featuring Ne-Yo                              0.291000  0.209000
# Faith Evans                                           0.213951  0.172711
# Fantasia                                              0.360249  0.104938
# Halsey                                                0.182748  0.147645
# Jaheim                                                0.205780  0.124622
# Jazmine Sullivan                                      0.209658  0.130147
# Jennifer Lopez Featuring LL Cool J                    0.265000  0.141000
# Jeremih                                               0.288418  0.207627
# Justin Bieber                                         0.320002  0.186610
# Kanye West, R. Kelly                                  0.211000  0.104000
# Lil Nas X                                             0.283846  0.153969
# Lil Skies                                             0.382500  0.115000
# Marques Houston                                       0.210378  0.133933
# Monica                                                0.200023  0.211975
# Musiq                                                 0.324406  0.181926
# Nick Jonas Featuring Tove Lo                          0.253000  0.144000
# Taylor Swift                                          0.186298  0.140975
# Zedd & Alessia Cara                                   0.253000  0.116000
# benny blanco & Juice WRLD Featuring Brendon Urie      0.166000  0.117000
# gnash Featuring Johnny Yukon                          0.195000  0.160000

# %%
len(df_inner6)
# Out:
# 23

# %%
perf_tempo = bb_all.groupby('Performer_x').mean()['tempo'].to_frame()
perf_tempo
# Out:
#                                                                                tempo
# Performer_x
# "Groove" Holmes                                                             93.66500
# "Little" Jimmy Dickens                                                     104.37400
# "Pookie" Hudson                                                                  NaN
# "Weird Al" Yankovic                                                        127.87756
# 'N Sync                                                                          NaN
# ...                                                                              ...
# will.i.am & Nicki Minaj                                                    130.09800
# will.i.am Featuring Justin Bieber                                          128.00000
# will.i.am Featuring Mick Jagger & Jennifer Lopez                           106.02400
# will.i.am Featuring Miley Cyrus                                            127.04200
# will.i.am Featuring Miley Cyrus, French Montana, Wiz Khalifa & DJ Mustard   96.45300
#
# [10061 rows x 1 columns]

# %%
selected_tempo = perf_tempo[(perf_tempo.tempo>103.832)&
                            (perf_tempo.tempo<133.973)]
selected_tempo
# Out:
#                                                        tempo
# Performer_x
# "Little" Jimmy Dickens                            104.374000
# "Weird Al" Yankovic                               127.877560
# 0                                                 115.839000
# 10cc                                              120.636061
# 112 Featuring Lil'z                               125.867000
# ...                                                      ...
# will.i.am & Britney Spears                        130.033000
# will.i.am & Nicki Minaj                           130.098000
# will.i.am Featuring Justin Bieber                 128.000000
# will.i.am Featuring Mick Jagger & Jennifer Lopez  106.024000
# will.i.am Featuring Miley Cyrus                   127.042000
#
# [3742 rows x 1 columns]

# %%
df_inner7 = pd.merge(df_inner6, selected_tempo, on='Performer_x', how='inner')
df_inner7
# Out:
#                               danceability   valence  speechiness  \
# Performer_x
# 10cc                              0.583280  0.522744     0.059845
# Dru Hill                          0.677326  0.491087     0.085821
# Faith Evans                       0.648719  0.535119     0.085249
# Halsey                            0.670697  0.478192     0.057210
# Jazmine Sullivan                  0.646028  0.589542     0.064340
# Jeremih                           0.687239  0.555104     0.057404
# Justin Bieber                     0.640524  0.518942     0.119881
# Lil Skies                         0.683500  0.475000     0.125500
# Monica                            0.633815  0.561908     0.087149
# Nick Jonas Featuring Tove Lo      0.653000  0.401000     0.082000
# Taylor Swift                      0.605309  0.476707     0.055582
#
#                               instrumentalness    energy  acousticness  \
# Performer_x
# 10cc                              4.388146e-03  0.522512      0.340788
# Dru Hill                          0.000000e+00  0.547638      0.240246
# Faith Evans                       2.429630e-07  0.586793      0.213951
# Halsey                            8.226239e-06  0.577432      0.182748
# Jazmine Sullivan                  0.000000e+00  0.621694      0.209658
# Jeremih                           0.000000e+00  0.553448      0.288418
# Justin Bieber                     2.440528e-04  0.604489      0.320002
# Lil Skies                         0.000000e+00  0.610000      0.382500
# Monica                            2.360761e-05  0.560826      0.200023
# Nick Jonas Featuring Tove Lo      0.000000e+00  0.623000      0.253000
# Taylor Swift                      7.053505e-04  0.655652      0.186298
#
#                               liveness       tempo
# Performer_x
# 10cc                          0.171202  120.636061
# Dru Hill                      0.164113  108.566384
# Faith Evans                   0.172711  120.767719
# Halsey                        0.147645  129.398406
# Jazmine Sullivan              0.130147  107.368139
# Jeremih                       0.207627  110.352881
# Justin Bieber                 0.186610  119.468909
# Lil Skies                     0.115000  129.633500
# Monica                        0.211975  117.187087
# Nick Jonas Featuring Tove Lo  0.144000  123.999000
# Taylor Swift                  0.140975  119.892869

# %%
len(df_inner7)
# Out:
# 11

# %%
bb_all[(bb_all.Performer_x == 'Halsey')].drop_duplicates(subset='SongID')
# Out:
#                                                         url     WeekID  \
# 4152     http://www.billboard.com/charts/hot-100/2017-06-17 2017-06-17
# 7623    https://www.billboard.com/charts/hot-100/2019-06-01 2019-06-01
# 8152    https://www.billboard.com/charts/hot-100/2019-09-28 2019-09-28
# 9078     http://www.billboard.com/charts/hot-100/2017-09-23 2017-09-23
# 16668    http://www.billboard.com/charts/hot-100/2017-02-04 2017-02-04
# 103855   http://www.billboard.com/charts/hot-100/2015-09-19 2015-09-19
# 198019  https://www.billboard.com/charts/hot-100/2018-10-20 2018-10-20
# 201772  https://www.billboard.com/charts/hot-100/2020-01-25 2020-01-25
#
#         Week Position              Song_x Performer_x  \
# 4152               26        Now Or Never      Halsey
# 7623               15           Nightmare      Halsey
# 8152               45           Graveyard      Halsey
# 9078               81         Bad At Love      Halsey
# 16668              77  Not Afraid Anymore      Halsey
# 103855             97       New Americana      Halsey
# 198019             18          Without Me      Halsey
# 201772             29   You Should Be Sad      Halsey
#
#                           SongID  Instance  Previous Week Position  \
# 4152          Now Or NeverHalsey         1                    26.0
# 7623             NightmareHalsey         1                     NaN
# 8152             GraveyardHalsey         1                     NaN
# 9078           Bad At LoveHalsey         1                     NaN
# 16668   Not Afraid AnymoreHalsey         1                     NaN
# 103855       New AmericanaHalsey         1                     NaN
# 198019          Without MeHalsey         1                     NaN
# 201772   You Should Be SadHalsey         1                     NaN
#
#         Peak Position  Weeks on Chart Performer_y              Song_y  \
# 4152               26               8      Halsey        Now Or Never
# 7623               15               1      Halsey           Nightmare
# 8152               45               1      Halsey           Graveyard
# 9078               81               1      Halsey         Bad At Love
# 16668              77               1      Halsey  Not Afraid Anymore
# 103855             97               1      Halsey       New Americana
# 198019             18               1      Halsey          Without Me
# 201772             29               1      Halsey   You Should Be Sad
#
#                                                                              spotify_genre  \
# 4152    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 7623    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 8152    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 9078    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 16668   ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 103855  ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 198019  ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 201772  ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
#
#               spotify_track_id spotify_track_preview_url  \
# 4152    7i2DJ88J7jQ8K7zqFX2fW8                       NaN
# 7623    340UVheS8z3ncW9TTUhAbc                       NaN
# 8152    6V9fHiv84WlVTg7CSnIVY2                       NaN
# 9078    7y9iMe8SOB6z3NoHE2OfXl                       NaN
# 16668   0wH7iJqYQnmUU09YGcQPHo                       NaN
# 103855  6Xs7OKt6i0Ddq8B4M5Dgvr                       NaN
# 198019  5p7ujcrUXASCNwRaWNHR1C                       NaN
# 201772  7lidXGPXPYLNThITAOTlkK                       NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 4152                     214801.0                     0.0
# 7623                     231998.0                     1.0
# 8152                     181805.0                     0.0
# 9078                     181279.0                     0.0
# 16668                    226786.0                     0.0
# 103855                   183808.0                     0.0
# 198019                   201660.0                     1.0
# 201772                   205473.0                     1.0
#
#                                                                                                                                                                                             spotify_track_album  \
# 4152                                                                                                                                                                         hopeless fountain kingdom (Deluxe)
# 7623                                                                                                                                                                                                  Nightmare
# 8152                                                                                                                                                                                                  Graveyard
# 9078                                                                                                                                                                         hopeless fountain kingdom (Deluxe)
# 16668                                                                                                                                                  Fifty Shades Darker (Original Motion Picture Soundtrack)
# 103855                                                                                                                                                                                                 BADLANDS
# 198019                                                                                                                                                                                               Without Me
# 201772  {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'}, 'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2', 'i...
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 4152           0.670   0.585   6.0    -4.861   0.0       0.0354        0.1070
# 7623           0.611   0.622   9.0    -5.075   0.0       0.0734        0.0188
# 8152           0.667   0.583  11.0    -5.127   0.0       0.0747        0.2310
# 9078           0.675   0.751   0.0    -3.539   1.0       0.0296        0.0604
# 16668          0.552   0.742   5.0    -6.935   0.0       0.0649        0.0026
# 103855         0.339   0.707   0.0    -5.121   0.0       0.0428        0.0113
# 198019         0.752   0.488   6.0    -7.050   1.0       0.0705        0.2970
# 201772         0.591   0.585   2.0    -6.350   1.0       0.0277        0.1430
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 4152            0.000001    0.1310    0.447  110.030             4.0
# 7623            0.000000    0.3590    0.538  146.110             4.0
# 8152            0.000045    0.1810    0.187   92.043             4.0
# 9078            0.000000    0.0893    0.612  118.384             4.0
# 16668           0.000059    0.1280    0.430  131.994             4.0
# 103855          0.000000    0.3370    0.359  173.993             4.0
# 198019          0.000009    0.0936    0.533  136.041             4.0
# 201772          0.000000    0.1090    0.324  110.940             4.0
#
#         spotify_track_popularity
# 4152                        73.0
# 7623                        77.0
# 8152                        89.0
# 9078                        79.0
# 16668                       61.0
# 103855                      67.0
# 198019                      89.0
# 201772                      77.0

# %%
Monica[(Monica.danceability>0.575)&
       (Monica.danceability<0.725)&
       (Monica.energy>0.51)&
       (Monica.energy<0.67)&
       (Monica.speechiness>0.05)&
       (Monica.speechiness<0.15)&
       (Monica.acousticness>0.16)&
       (Monica.acousticness<0.42)].drop_duplicates(subset='SongID')
# Out:
#                                                      url     WeekID  \
# 4836  http://www.billboard.com/charts/hot-100/2003-04-26 2003-04-26
#
#       Week Position   Song_x Performer_x         SongID  Instance  \
# 4836             66  So Gone      Monica  So GoneMonica         1
#
#       Previous Week Position  Peak Position  Weeks on Chart Performer_y  \
# 4836                     NaN             66               1      Monica
#
#        Song_y  \
# 4836  So Gone
#
#                                                                                                                                  spotify_genre  \
# 4836  ['dance pop', 'deep pop r&b', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'pop rap', 'quiet storm', 'r&b', 'urban contemporary']
#
#             spotify_track_id  \
# 4836  6BIcjFZIVDZxNAcofRFPx4
#
#                                                                                         spotify_track_preview_url  \
# 4836  https://p.scdn.co/mp3-preview/e7beb57a931042856416cebdc5ad88bd9bd0a3c4?cid=b8d3901151d34489a160e3cf0ab1fa94
#
#       spotify_track_duration_ms  spotify_track_explicit spotify_track_album  \
# 4836                   242773.0                     0.0     After The Storm
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 4836         0.618   0.552  8.0    -6.863   1.0       0.0981         0.176
#
#       instrumentalness  liveness  valence   tempo  time_signature  \
# 4836               0.0     0.252    0.586  81.975             4.0
#
#       spotify_track_popularity
# 4836                      68.0

# %%
bb_all[(bb_all.danceability>0.63)].drop_duplicates(subset='SongID')
# Out:
#                                                        url     WeekID  \
# 14      http://www.billboard.com/charts/hot-100/1971-04-24 1971-04-24
# 26      http://www.billboard.com/charts/hot-100/1974-07-13 1974-07-13
# 87      http://www.billboard.com/charts/hot-100/2002-09-28 2002-09-28
# 132     http://www.billboard.com/charts/hot-100/1986-12-27 1986-12-27
# 147     http://www.billboard.com/charts/hot-100/1995-10-21 1995-10-21
# ...                                                    ...        ...
# 298187  http://www.billboard.com/charts/hot-100/2002-04-27 2002-04-27
# 298231  http://www.billboard.com/charts/hot-100/2007-07-21 2007-07-21
# 298249  http://www.billboard.com/charts/hot-100/1983-09-24 1983-09-24
# 298334  http://www.billboard.com/charts/hot-100/1992-09-05 1992-09-05
# 298347  http://www.billboard.com/charts/hot-100/1964-03-21 1964-03-21
#
#         Week Position                           Song_x  \
# 14                 96      Don't Knock My Love - Pt. 1
# 26                 90              Don't Knock My Love
# 87                 78                   Don't Know Why
# 132                87          Don't Leave Me This Way
# 147                67  Automatic Lover (Call For Love)
# ...               ...                              ...
# 298187             83         You Know That I Love You
# 298231             68              You Know What It Is
# 298249             90              You Know What To Do
# 298334             83                   You Lied To Me
# 298347             88           You Lied To Your Daddy
#
#                        Performer_x  \
# 14                  Wilson Pickett
# 26        Diana Ross & Marvin Gaye
# 87                     Norah Jones
# 132                 The Communards
# 147                     Real McCoy
# ...                            ...
# 298187                Donell Jones
# 298231  T.I. Featuring Wyclef Jean
# 298249                 Carly Simon
# 298334                Cathy Dennis
# 298347                    The Tams
#
#                                                SongID  Instance  \
# 14          Don't Knock My Love - Pt. 1Wilson Pickett         1
# 26        Don't Knock My LoveDiana Ross & Marvin Gaye         1
# 87                          Don't Know WhyNorah Jones         1
# 132             Don't Leave Me This WayThe Communards         1
# 147         Automatic Lover (Call For Love)Real McCoy         1
# ...                                               ...       ...
# 298187           You Know That I Love YouDonell Jones         1
# 298231  You Know What It IsT.I. Featuring Wyclef Jean         1
# 298249                 You Know What To DoCarly Simon         1
# 298334                     You Lied To MeCathy Dennis         1
# 298347                 You Lied To Your DaddyThe Tams         1
#
#         Previous Week Position  Peak Position  Weeks on Chart  \
# 14                         NaN             96               1
# 26                         NaN             90               1
# 87                         NaN             78               1
# 132                        NaN             87               1
# 147                        NaN             67               1
# ...                        ...            ...             ...
# 298187                     NaN             83               1
# 298231                     NaN             68               1
# 298249                     NaN             90               1
# 298334                     NaN             83               1
# 298347                     NaN             88               1
#
#                        Performer_y                           Song_y  \
# 14                  Wilson Pickett      Don't Knock My Love - Pt. 1
# 26        Diana Ross & Marvin Gaye              Don't Knock My Love
# 87                     Norah Jones                   Don't Know Why
# 132                 The Communards          Don't Leave Me This Way
# 147                     Real McCoy  Automatic Lover (Call For Love)
# ...                            ...                              ...
# 298187                Donell Jones         You Know That I Love You
# 298231  T.I. Featuring Wyclef Jean              You Know What It Is
# 298249                 Carly Simon              You Know What To Do
# 298334                Cathy Dennis                   You Lied To Me
# 298347                    The Tams           You Lied To Your Daddy
#
#                                                                                                                                           spotify_genre  \
# 14      ['brill building pop', 'classic rock', 'classic soul', 'folk rock', 'funk', 'memphis soul', 'motown', 'rock-and-roll', 'soul', 'southern soul']
# 26                                                    ['adult standards', 'disco', 'funk', 'mellow gold', 'motown', 'quiet storm', 'soft rock', 'soul']
# 87                                                                           ['adult standards', 'contemporary vocal jazz', 'neo mellow', 'vocal jazz']
# 132                                                                    ['dance rock', 'hi-nrg', 'new romantic', 'new wave', 'new wave pop', 'synthpop']
# 147                                                             ['bubblegum dance', 'diva house', 'eurodance', 'europop', 'german techno', 'hip house']
# ...                                                                                                                                                 ...
# 298187                                    ['dance pop', 'hip hop', 'hip pop', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary']
# 298231                         ['atl hip hop', 'dance pop', 'dirty south rap', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
# 298249                                      ['adult standards', 'classic uk pop', 'folk', 'folk rock', 'mellow gold', 'singer-songwriter', 'soft rock']
# 298334                                                                                                                   ['diva house', 'new wave pop']
# 298347                                                                                                       ['beach music', 'motown', 'northern soul']
#
#               spotify_track_id  \
# 14      7cyLwgSVf3AnKXetNRWiTa
# 26      4ESNSk1yvpJO3UmANTcVeI
# 87      6ybViy2qrO9sIi41EgRJgx
# 132     0ire4j2mcGovF5JA1D2cTp
# 147     7CEPvXcCMeCSBrMI72ayLm
# ...                        ...
# 298187  5QiTs0egWAq0k2O8HWKoEP
# 298231  5Tc1KlDWyRnLLXL1y6ufsM
# 298249  6bHJK5foTbt9sWHYWSqG3x
# 298334  7zUXJzKqVdUKaMcgSB21nL
# 298347  1htnmqG4C26nDLr7Hx50aR
#
#                                                                                           spotify_track_preview_url  \
# 14      https://p.scdn.co/mp3-preview/5d3332b4ae616cd2157f948f7329b20470714a95?cid=b8d3901151d34489a160e3cf0ab1fa94
# 26                                                                                                              NaN
# 87                                                                                                              NaN
# 132     https://p.scdn.co/mp3-preview/8cf6be2590b40b888c4141eb6b96ccc3e9ca8d66?cid=b8d3901151d34489a160e3cf0ab1fa94
# 147     https://p.scdn.co/mp3-preview/0f967dae3089c92dbd25838769cd4291662c50ea?cid=b8d3901151d34489a160e3cf0ab1fa94
# ...                                                                                                             ...
# 298187  https://p.scdn.co/mp3-preview/81afaf5bce91608aebcce7f5fef0fefe2bf2b102?cid=b8d3901151d34489a160e3cf0ab1fa94
# 298231  https://p.scdn.co/mp3-preview/4c60c597932679c45c5e97f820caf917909dfd5e?cid=b8d3901151d34489a160e3cf0ab1fa94
# 298249  https://p.scdn.co/mp3-preview/933c587a803b3d82f2e6151335ac98e7b72cda09?cid=b8d3901151d34489a160e3cf0ab1fa94
# 298334                                                                                                          NaN
# 298347                                                                                                          NaN
#
#         spotify_track_duration_ms  spotify_track_explicit  \
# 14                       136400.0                     0.0
# 26                       143440.0                     0.0
# 87                       186146.0                     0.0
# 132                      271066.0                     0.0
# 147                      227933.0                     0.0
# ...                           ...                     ...
# 298187                   260066.0                     0.0
# 298231                   287133.0                     1.0
# 298249                   252120.0                     0.0
# 298334                   327040.0                     0.0
# 298347                   133800.0                     0.0
#
#                                    spotify_track_album  danceability  energy  \
# 14                     The Very Best Of Wilson Pickett         0.731   0.701
# 26                                      Diana & Marvin         0.658   0.692
# 87                                   Come Away With Me         0.732   0.198
# 132                                         Communards         0.640   0.926
# 147                         Platinum & Gold Collection         0.688   0.980
# ...                                                ...           ...     ...
# 298187                                    Life Goes On         0.767   0.494
# 298231                                  T.I. VS T.I.P.         0.657   0.853
# 298249                                   Hello Big Man         0.741   0.591
# 298334                                Into The Skyline         0.761   0.851
# 298347  Hey Girl Don't Bother Me: The Best Of The Tams         0.782   0.371
#
#          key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 14       7.0    -8.722   0.0       0.0287        0.1570          0.000007
# 26       9.0    -8.380   0.0       0.0467        0.1750          0.000016
# 87       5.0   -11.775   1.0       0.0280        0.8830          0.000011
# 132      3.0    -5.597   1.0       0.0322        0.1350          0.000002
# 147      5.0    -4.862   0.0       0.0340        0.0693          0.462000
# ...      ...       ...   ...          ...           ...               ...
# 298187   6.0    -5.349   1.0       0.0421        0.1360          0.000277
# 298231   1.0    -4.757   0.0       0.2520        0.1700          0.000000
# 298249   6.0   -13.968   0.0       0.0312        0.1020          0.000396
# 298334   4.0    -9.779   0.0       0.0524        0.0546          0.122000
# 298347  10.0   -14.501   1.0       0.0639        0.5970          0.000000
#
#         liveness  valence    tempo  time_signature  spotify_track_popularity
# 14        0.0595    0.961  107.521             4.0                      26.0
# 26        0.0630    0.910  115.311             4.0                      27.0
# 87        0.0659    0.618   88.174             4.0                      74.0
# 132       0.1340    0.901  131.997             4.0                      65.0
# 147       0.1600    0.538  132.992             4.0                      36.0
# ...          ...      ...      ...             ...                       ...
# 298187    0.0603    0.801   96.003             4.0                      42.0
# 298231    0.0956    0.746  173.066             4.0                      46.0
# 298249    0.1590    0.933  126.589             4.0                      42.0
# 298334    0.0360    0.752  122.065             4.0                      17.0
# 298347    0.3110    0.828  120.851             4.0                       5.0
#
# [10641 rows x 31 columns]
